# %%
# Importing libaries
from bs4 import BeautifulSoup
from bs4 import SoupStrainer
import requests as r
import re
from time import time
import math
import chardet
import pandas as pd
import os

# %% [markdown]
# ### Specific page scraper from leaderboard:

# %%
# '''
# URL : page url
# page_no : number of page to scrape
# pl : programming language
# problem_id: unique problem id for each problem
# count_dict : Tracks the count of each category scraped
# '''
# #Defining header
# header = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.5195.127'}
# # Scrape only a specific page
# def scrape_page(url,page_no,pl,problem_id,count_dict = {}):

#     page_url = f'{url}/leaderboard?filter={pl}&filter_on=language&limit=100&page={page_no}'
#     print(f'Page being scraped rightnow: {page_url}')
#     print(f'0% Scraped')
#     try:
#         page_html = r.get(page_url, headers=header).text
#         soup = BeautifulSoup(page_html, "html.parser")
#         rows_html = soup.find_all("div", {"class": "table-row flex"})
#     except:
#         return count_dict
#     no_rows = len(rows_html)
#     # Getting "data-balloon" values from each rows
#     for page_no,row_html in enumerate(rows_html):
#             # Get education,work information
#             try:
#                 user_url = ("https://www.hackerrank.com" + row_html.find("a", {"data-analytics":"LeaderboardListUserName"})["href"])
#             except:
#                 user_url = "Null"
                
#             if user_url != "Null":
#                 profile_html = r.get(user_url, headers=header).text
#                 soup_profile = BeautifulSoup(profile_html, "html.parser", parse_only = SoupStrainer("section", {"class":"profile-details-section"}))
#                 company_html = soup_profile.find("div", {"class":"profile-details-field profile-details-company"})
#                 school_html = soup_profile.find("div", {"class":"profile-details-field profile-details-school"})
#                 company = "Null"
#                 school = "Null"
#                 if company_html is not None:
#                      company = company_html.find("p",{"class":"profile-details-value"}).text
#                 if school_html is not None:
#                      school = school_html.find("p",{"class":"profile-details-value"}).text 
#             else:
#                 company = "Null"
#                 school = "Null"

#             # Get rank,country,score info
#             rank_country_score_html =  row_html.find_all("span", {"data-balloon-pos":True})
#             try:
#                 rank = rank_country_score_html[0]["data-balloon"]
#             except: 
#                 rank = "Null"
#             try:
#                 country = rank_country_score_html[1]["data-balloon"] or "Null"
#             except:
#                 country = "Null"
#             try:
#                 score = rank_country_score_html[2]["data-balloon"] or "Null"
#             except:
#                 score = "Null"
#             key_name = f'{problem_id}_{pl}_{country}_{score}_{school}_{company}'
#             #print(f'{problem_id},{pl},{country},{school},{company}: {user_url}')
#             if key_name not in count_dict.keys():
#                  count_dict[key_name] = 1
#             else:
#                  count_dict[key_name] = count_dict[key_name] + 1 
#             if (page_no+1) % 5 == 0:
#                 print(f'{round((page_no+1)*100/no_rows,1)}% of page is scraped')
                
#     return count_dict

# %%
'''
URL : page url
page_no : number of page to scrape
pl : programming language
problem_id: unique problem id for each problem
count_dict : Tracks the count of each category scraped
'''
#Defining header
header = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.5195.127'}
# Scrape only a specific page
def scrape_page(url,page_no,pl,problem_id,count_dict = {}):

    page_url = f'{url}/leaderboard?filter={pl}&filter_on=language&limit=100&page={page_no}'
    print(f'Page being scraped rightnow: {page_url}')
    print(f'0% Scraped')
    try:
        page_html = r.get(page_url, headers=header).text
        soup = BeautifulSoup(page_html, "html.parser")
        rows_html = soup.find_all("div", {"class": "table-row flex"})
    except:
        return count_dict
    no_rows = len(rows_html)
    # Getting "data-balloon" values from each rows
    for page_no,row_html in enumerate(rows_html):

            # Get rank,country,score info
            rank_country_score_html =  row_html.find_all("span", {"data-balloon-pos":True})
            try:
                rank = rank_country_score_html[0]["data-balloon"]
            except: 
                rank = "Null"
            try:
                country = rank_country_score_html[1]["data-balloon"] or "Null"
            except:
                country = "Null"
            try:
                score = rank_country_score_html[2]["data-balloon"] or "Null"
            except:
                score = "Null"
            key_name = f'{problem_id}_{pl}_{country}_{score}'
            #print(f'{problem_id},{pl},{country},{school},{company}: {user_url}')
            if key_name not in count_dict.keys():
                 count_dict[key_name] = 1
            else:
                 count_dict[key_name] = count_dict[key_name] + 1 
            if (page_no+1) % 5 == 0:
                print(f'{round((page_no+1)*100/no_rows,1)}% of page is scraped')
                
    return count_dict

# %%
# Scrape leaderboard from page 3 for solutions written in c++
start = time()
scrape_page("https://www.hackerrank.com/challenges/string-function-calculation",3,"cpp",1)
end = time()
print(f'Time taken: {round((end-start)/60,3)} mins')
# Out:
# Page being scraped rightnow: https://www.hackerrank.com/challenges/string-function-calculation/leaderboard?filter=cpp&filter_on=language&limit=100&page=3
# 0% Scraped
# 5.0% of page is scraped
# 10.0% of page is scraped
# 15.0% of page is scraped
# 20.0% of page is scraped
# 25.0% of page is scraped
# 30.0% of page is scraped
# 35.0% of page is scraped
# 40.0% of page is scraped
# 45.0% of page is scraped
# 50.0% of page is scraped
# 55.0% of page is scraped
# 60.0% of page is scraped
# 65.0% of page is scraped
# 70.0% of page is scraped
# 75.0% of page is scraped
# 80.0% of page is scraped
# 85.0% of page is scraped
# 90.0% of page is scraped
# 95.0% of page is scraped
# 100.0% of page is scraped
# Time taken: 0.074 mins

# %% [markdown]
# The **keys** of the `count_dict` dictionary are in the form of `attr1_attr2_...` and **value** of each key represents the count of this category.

# %% [markdown]
# ### Get list of programming languages:

# %%
# Get list of programming languages that solutions can be written in
pls_html = '<ul class="ac-menu"><li class="list-item "><span>c</span></li><li class="list-item "><span>cpp</span></li><li class="list-item "><span>java</span></li><li class="list-item "><span>csharp</span></li><li class="list-item "><span>haskell</span></li><li class="list-item "><span>php</span></li><li class="list-item "><span>python</span></li><li class="list-item "><span>ruby</span></li><li class="list-item "><span>perl</span></li><li class="list-item "><span>bash</span></li><li class="list-item "><span>clojure</span></li><li class="list-item "><span>scala</span></li><li class="list-item "><span>code</span></li><li class="list-item "><span>text</span></li><li class="list-item "><span>brainfuck</span></li><li class="list-item "><span>javascript</span></li><li class="list-item "><span>typescript</span></li><li class="list-item "><span>lua</span></li><li class="list-item "><span>sbcl</span></li><li class="list-item "><span>erlang</span></li><li class="list-item "><span>go</span></li><li class="list-item "><span>d</span></li><li class="list-item "><span>ocaml</span></li><li class="list-item "><span>pascal</span></li><li class="list-item "><span>python3</span></li><li class="list-item "><span>groovy</span></li><li class="list-item "><span>objectivec</span></li><li class="list-item "><span>text_pseudo</span></li><li class="list-item "><span>fsharp</span></li><li class="list-item "><span>visualbasic</span></li><li class="list-item "><span>lolcode</span></li><li class="list-item "><span>smalltalk</span></li><li class="list-item "><span>tcl</span></li><li class="list-item "><span>whitespace</span></li><li class="list-item "><span>html</span></li><li class="list-item "><span>css</span></li><li class="list-item "><span>java8</span></li><li class="list-item "><span>java15</span></li><li class="list-item "><span>kotlin</span></li><li class="list-item "><span>octave</span></li><li class="list-item "><span>r</span></li><li class="list-item "><span>xquery</span></li><li class="list-item "><span>racket</span></li><li class="list-item "><span>cobol</span></li><li class="list-item "><span>xml</span></li><li class="list-item "><span>rust</span></li><li class="list-item "><span>fortran</span></li><li class="list-item "><span>swift</span></li><li class="list-item "><span>oracle</span></li><li class="list-item "><span>tsql</span></li><li class="list-item "><span>db2</span></li><li class="list-item "><span>mysql</span></li><li class="list-item "><span>sql</span></li><li class="list-item "><span>ada</span></li><li class="list-item "><span>cpp14</span></li><li class="list-item "><span>cpp20</span></li><li class="list-item "><span>coffeescript</span></li><li class="list-item "><span>elixir</span></li><li class="list-item "><span>pypy</span></li><li class="list-item "><span>pypy3</span></li><li class="list-item "><span>julia</span></li><li class="list-item "><span>verilog</span></li></ul>'
soup = BeautifulSoup(pls_html, "html.parser")
pls = list(map(lambda pl_html: pl_html.text,soup.contents[0].contents))
print(pls)
# Out:
# ['c', 'cpp', 'java', 'csharp', 'haskell', 'php', 'python', 'ruby', 'perl', 'bash', 'clojure', 'scala', 'code', 'text', 'brainfuck', 'javascript', 'typescript', 'lua', 'sbcl', 'erlang', 'go', 'd', 'ocaml', 'pascal', 'python3', 'groovy', 'objectivec', 'text_pseudo', 'fsharp', 'visualbasic', 'lolcode', 'smalltalk', 'tcl', 'whitespace', 'html', 'css', 'java8', 'java15', 'kotlin', 'octave', 'r', 'xquery', 'racket', 'cobol', 'xml', 'rust', 'fortran', 'swift', 'oracle', 'tsql', 'db2', 'mysql', 'sql', 'ada', 'cpp14', 'cpp20', 'coffeescript', 'elixir', 'pypy', 'pypy3', 'julia', 'verilog']

# %% [markdown]
# ### Entire leaderboard scraper:

# %%
# Scrape all pages in one leaderboard (In specific programming language)
def scrape_all_pages(url,pl,problem_id,p,count_dict = {}):
    # Count Dictionary contains count for each combination of country, score.
    # Fetching number of pages
    header = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.5195.127'}
    page_html = r.get(f'{url}/leaderboard?filter={pl}&filter_on=language&limit=100',headers=header).text
    soup = BeautifulSoup(page_html, "html.parser")
    last_page_no = soup.find_all("a", {"class":"pagination-button"})[-2].text
    print(f'Number of pages in leaderboard: {last_page_no}')
    # Get data from each page
    #for page_no in range(1,last_page_no + 1):
    for page_no in range(1,int(last_page_no) + 1,math.ceil(1/p)):
        # Get data from a single page and update Count Dictionary
        scrape_page(url, page_no, pl, problem_id, count_dict)
        print(f'Page {page_no} finished scraping \n\n')
    return count_dict

# %%
# Scrape all pages in one leaderboard (In all programming languages)
def scrape_problem(problem_name,problem_id,p):
    problem_count_dict = {}
    for pl in pls:
        os.write(1,f'\n --- Scraping in {pl} language: \n'.encode())
        url_ = f'https://www.hackerrank.com/challenges/{problem_name}/leaderboard?filter={pl}&filter_on=language&limit=100'
        page_html = r.get(url_, headers=header).text
        soup = BeautifulSoup(page_html, "html.parser")
        rows_html = soup.find_all("div", {"class": "table-row flex"})
        if len(rows_html) == 0:
            print("Found nothing")
            continue
        else:
            url = f'https://www.hackerrank.com/challenges/{problem_name}'
            scrape_all_pages(url,pl,problem_id,p,problem_count_dict)
    return problem_count_dict

# %%
# Output data to csv
def output_to_csv(path,count_dict):
    with open(path,"a",encoding="utf-8") as file:
         for key in count_dict:
            try:
                row = f'{key.replace("_",";")};{count_dict[key]}\n'
                #print(chardet.detect(row.encode()))
                #print(row)
                file.write(row)
            except:
                print("Error occured writing this row")

#output_to_csv("data.csv",test_data_2)

# %% [markdown]
# ### Get list of problems:

# %%
alog_list = []
algo_no_pages = 0
# Getting all algorthims problems details
algo_problems_html = '''<section class="list-container left-pane"><div class="recommended-challenge pjB"><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="day-of-the-programmer" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="15" data-attr-10="0.9" data-attr11="false" href="/challenges/day-of-the-programmer?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Day of the Programmer<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 15</span><span class="success-ratio detail-item">Success Rate: 90.21%</span></div></h4></div></div></header><div class="preview-box"><div class="preview-content">Given year, determine date of the 256th day of the year.</div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></div></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a></div><div><div class="challenges-list"><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="solve-me-first" data-attr3="code" data-attr4="true" data-attr5="true" data-attr7="1" data-attr-10="0.9950288377707732" data-attr11="false" href="/challenges/solve-me-first?isFullScreen=true"><div class="single-item challenges-list-view-v2 first-challenge cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Solve Me First<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 1</span><span class="success-ratio detail-item">Success Rate: 98.29%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content has-icon align-icon-right"><span class="ui-text" aria-hidden="false">Solved</span><i class="ui-icon-check-circle ui-btn-icon"></i></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="simple-array-sum" data-attr3="code" data-attr4="true" data-attr5="true" data-attr7="10" data-attr-10="0.9" data-attr11="false" href="/challenges/simple-array-sum?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Simple Array Sum<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 10</span><span class="success-ratio detail-item">Success Rate: 94.27%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content has-icon align-icon-right"><span class="ui-text" aria-hidden="false">Solved</span><i class="ui-icon-check-circle ui-btn-icon"></i></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="compare-the-triplets" data-attr3="code" data-attr4="true" data-attr5="true" data-attr7="10" data-attr-10="0.9" data-attr11="false" href="/challenges/compare-the-triplets?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Compare the Triplets<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 10</span><span class="success-ratio detail-item">Success Rate: 95.50%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content has-icon align-icon-right"><span class="ui-text" aria-hidden="false">Solved</span><i class="ui-icon-check-circle ui-btn-icon"></i></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a href="https://www.hackerrank.com/dtcc-gracehopper-codeathon" rel="noopener noreferrer" target="_blank" class="challenge-list-item promo-challenge-list-item"><div class="single-item challenges-list-view-v2 cursor"><div class="individual-challenge-card-v2 content--list-v2 track_content" style="background-color: rgb(0, 150, 214);"><div class="content--list_body"><div class="promo-content"><header class="content--list_header-v2"><div class="challenge-name-details "><h4 class="challengecard-title" style="color: rgb(0, 0, 0);">DTCC Grace Hopper<div class="card-details" style="color: rgb(0, 0, 0);">DTCC CODE-A-THON on 14th Oct'22 on HackerRank</div></h4></div><div class="cta-container"><div class="ctas"><img src="https://hr-assets.s3.amazonaws.com/contests/2153b032-ac13-4035-9919-88f0f6d92035/dtcc.png" alt="DTCC logo" class="promo-icon branding-promo-logo"></div></div></header></div></div></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="a-very-big-sum" data-attr3="code" data-attr4="true" data-attr5="true" data-attr7="10" data-attr-10="0.9" data-attr11="false" href="/challenges/a-very-big-sum?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">A Very Big Sum<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 10</span><span class="success-ratio detail-item">Success Rate: 98.79%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content has-icon align-icon-right"><span class="ui-text" aria-hidden="false">Solved</span><i class="ui-icon-check-circle ui-btn-icon"></i></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="diagonal-difference" data-attr3="code" data-attr4="true" data-attr5="true" data-attr7="10" data-attr-10="0.9" data-attr11="false" href="/challenges/diagonal-difference?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Diagonal Difference<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 10</span><span class="success-ratio detail-item">Success Rate: 95.89%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content has-icon align-icon-right"><span class="ui-text" aria-hidden="false">Solved</span><i class="ui-icon-check-circle ui-btn-icon"></i></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="plus-minus" data-attr3="code" data-attr4="true" data-attr5="true" data-attr7="10" data-attr-10="0.9" data-attr11="false" href="/challenges/plus-minus?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Plus Minus<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 10</span><span class="success-ratio detail-item">Success Rate: 98.37%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content has-icon align-icon-right"><span class="ui-text" aria-hidden="false">Solved</span><i class="ui-icon-check-circle ui-btn-icon"></i></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="staircase" data-attr3="code" data-attr4="true" data-attr5="true" data-attr7="10" data-attr-10="0.9" data-attr11="false" href="/challenges/staircase?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Staircase<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 10</span><span class="success-ratio detail-item">Success Rate: 98.35%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Remove bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star-filled star-icon-filled"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content has-icon align-icon-right"><span class="ui-text" aria-hidden="false">Solved</span><i class="ui-icon-check-circle ui-btn-icon"></i></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="mini-max-sum" data-attr3="code" data-attr4="true" data-attr5="true" data-attr7="10" data-attr-10="0.9" data-attr11="false" href="/challenges/mini-max-sum?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Mini-Max Sum<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 10</span><span class="success-ratio detail-item">Success Rate: 94.28%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Remove bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star-filled star-icon-filled"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content has-icon align-icon-right"><span class="ui-text" aria-hidden="false">Solved</span><i class="ui-icon-check-circle ui-btn-icon"></i></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="birthday-cake-candles" data-attr3="code" data-attr4="true" data-attr5="true" data-attr7="10" data-attr-10="0.9" data-attr11="false" href="/challenges/birthday-cake-candles?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Birthday Cake Candles<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 10</span><span class="success-ratio detail-item">Success Rate: 97.00%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Remove bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star-filled star-icon-filled"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content has-icon align-icon-right"><span class="ui-text" aria-hidden="false">Solved</span><i class="ui-icon-check-circle ui-btn-icon"></i></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="time-conversion" data-attr3="code" data-attr4="true" data-attr5="true" data-attr7="15" data-attr-10="0.9" data-attr11="false" href="/challenges/time-conversion?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Time Conversion<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 15</span><span class="success-ratio detail-item">Success Rate: 91.86%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Remove bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star-filled star-icon-filled"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content has-icon align-icon-right"><span class="ui-text" aria-hidden="false">Solved</span><i class="ui-icon-check-circle ui-btn-icon"></i></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="grading" data-attr3="code" data-attr4="true" data-attr5="true" data-attr7="10" data-attr-10="0.9" data-attr11="false" href="/challenges/grading?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Grading Students<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 10</span><span class="success-ratio detail-item">Success Rate: 96.49%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content has-icon align-icon-right"><span class="ui-text" aria-hidden="false">Solved</span><i class="ui-icon-check-circle ui-btn-icon"></i></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="apple-and-orange" data-attr3="code" data-attr4="true" data-attr5="true" data-attr7="10" data-attr-10="0.9" data-attr11="false" href="/challenges/apple-and-orange?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Apple and Orange<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 10</span><span class="success-ratio detail-item">Success Rate: 96.21%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content has-icon align-icon-right"><span class="ui-text" aria-hidden="false">Solved</span><i class="ui-icon-check-circle ui-btn-icon"></i></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="kangaroo" data-attr3="code" data-attr4="true" data-attr5="true" data-attr7="10" data-attr-10="0.9" data-attr11="false" href="/challenges/kangaroo?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Number Line Jumps<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 10</span><span class="success-ratio detail-item">Success Rate: 89.19%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content has-icon align-icon-right"><span class="ui-text" aria-hidden="false">Solved</span><i class="ui-icon-check-circle ui-btn-icon"></i></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="between-two-sets" data-attr3="code" data-attr4="true" data-attr5="true" data-attr7="10" data-attr-10="0.9" data-attr11="false" href="/challenges/between-two-sets?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Between Two Sets<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 10</span><span class="success-ratio detail-item">Success Rate: 90.24%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Remove bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star-filled star-icon-filled"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content has-icon align-icon-right"><span class="ui-text" aria-hidden="false">Solved</span><i class="ui-icon-check-circle ui-btn-icon"></i></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="breaking-best-and-worst-records" data-attr3="code" data-attr4="true" data-attr5="true" data-attr7="10" data-attr-10="0.9" data-attr11="false" href="/challenges/breaking-best-and-worst-records?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Breaking the Records<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 10</span><span class="success-ratio detail-item">Success Rate: 98.52%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content has-icon align-icon-right"><span class="ui-text" aria-hidden="false">Solved</span><i class="ui-icon-check-circle ui-btn-icon"></i></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="the-birthday-bar" data-attr3="code" data-attr4="true" data-attr5="true" data-attr7="10" data-attr-10="0.9" data-attr11="false" href="/challenges/the-birthday-bar?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Subarray Division<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 10</span><span class="success-ratio detail-item">Success Rate: 93.98%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Remove bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star-filled star-icon-filled"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content has-icon align-icon-right"><span class="ui-text" aria-hidden="false">Solved</span><i class="ui-icon-check-circle ui-btn-icon"></i></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="divisible-sum-pairs" data-attr3="code" data-attr4="true" data-attr5="true" data-attr7="10" data-attr-10="0.9" data-attr11="false" href="/challenges/divisible-sum-pairs?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Divisible Sum Pairs<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 10</span><span class="success-ratio detail-item">Success Rate: 97.64%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Remove bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star-filled star-icon-filled"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content has-icon align-icon-right"><span class="ui-text" aria-hidden="false">Solved</span><i class="ui-icon-check-circle ui-btn-icon"></i></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="migratory-birds" data-attr3="code" data-attr4="true" data-attr5="true" data-attr7="10" data-attr-10="0.9" data-attr11="false" href="/challenges/migratory-birds?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Migratory Birds<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 10</span><span class="success-ratio detail-item">Success Rate: 91.70%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content has-icon align-icon-right"><span class="ui-text" aria-hidden="false">Solved</span><i class="ui-icon-check-circle ui-btn-icon"></i></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="bon-appetit" data-attr3="code" data-attr4="true" data-attr5="true" data-attr7="10" data-attr-10="0.9" data-attr11="false" href="/challenges/bon-appetit?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Bill Division<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 10</span><span class="success-ratio detail-item">Success Rate: 97.97%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content has-icon align-icon-right"><span class="ui-text" aria-hidden="false">Solved</span><i class="ui-icon-check-circle ui-btn-icon"></i></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="sock-merchant" data-attr3="code" data-attr4="true" data-attr5="true" data-attr7="10" data-attr-10="0.9" data-attr11="false" href="/challenges/sock-merchant?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Sales by Match<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 10</span><span class="success-ratio detail-item">Success Rate: 92.29%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content has-icon align-icon-right"><span class="ui-text" aria-hidden="false">Solved</span><i class="ui-icon-check-circle ui-btn-icon"></i></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="drawing-book" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="10" data-attr-10="0.9" data-attr11="false" href="/challenges/drawing-book?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Drawing Book <div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 10</span><span class="success-ratio detail-item">Success Rate: 89.73%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="counting-valleys" data-attr3="code" data-attr7="15" data-attr-10="0.9" data-attr11="false" href="/challenges/counting-valleys?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Counting Valleys<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 15</span><span class="success-ratio detail-item">Success Rate: 94.96%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="electronics-shop" data-attr3="code" data-attr7="15" data-attr-10="0.9" data-attr11="false" href="/challenges/electronics-shop?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Electronics Shop<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 15</span><span class="success-ratio detail-item">Success Rate: 92.42%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="cats-and-a-mouse" data-attr3="code" data-attr7="15" data-attr-10="0.9" data-attr11="false" href="/challenges/cats-and-a-mouse?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Cats and a Mouse<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 15</span><span class="success-ratio detail-item">Success Rate: 98.06%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="magic-square-forming" data-attr3="code" data-attr7="20" data-attr-10="0.7" data-attr11="false" href="/challenges/magic-square-forming?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Forming a Magic Square<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 77.27%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="picking-numbers" data-attr3="code" data-attr7="20" data-attr-10="0.9" data-attr11="false" href="/challenges/picking-numbers?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Picking Numbers<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 89.93%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="climbing-the-leaderboard" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="20" data-attr-10="0.7" data-attr11="false" href="/challenges/climbing-the-leaderboard?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Climbing the Leaderboard<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 58.98%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="the-hurdle-race" data-attr3="code" data-attr7="15" data-attr-10="0.9" data-attr11="false" href="/challenges/the-hurdle-race?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">The Hurdle Race<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 15</span><span class="success-ratio detail-item">Success Rate: 98.86%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="designer-pdf-viewer" data-attr3="code" data-attr7="20" data-attr-10="0.9" data-attr11="false" href="/challenges/designer-pdf-viewer?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Designer PDF Viewer<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 98.83%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="utopian-tree" data-attr3="code" data-attr7="20" data-attr-10="0.9501810813141329" data-attr11="false" href="/challenges/utopian-tree?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Utopian Tree<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 97.81%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="angry-professor" data-attr3="code" data-attr7="20" data-attr-10="0.9" data-attr11="false" href="/challenges/angry-professor?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Angry Professor<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 96.23%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="beautiful-days-at-the-movies" data-attr3="code" data-attr7="15" data-attr-10="0.9" data-attr11="false" href="/challenges/beautiful-days-at-the-movies?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Beautiful Days at the Movies<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 15</span><span class="success-ratio detail-item">Success Rate: 96.48%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="strange-advertising" data-attr3="code" data-attr7="15" data-attr-10="0.9" data-attr11="false" href="/challenges/strange-advertising?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Viral Advertising<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 15</span><span class="success-ratio detail-item">Success Rate: 98.66%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="save-the-prisoner" data-attr3="code" data-attr7="15" data-attr-10="0.9" data-attr11="false" href="/challenges/save-the-prisoner?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Save the Prisoner!<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 15</span><span class="success-ratio detail-item">Success Rate: 81.29%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="circular-array-rotation" data-attr3="code" data-attr7="20" data-attr-10="0.9" data-attr11="false" href="/challenges/circular-array-rotation?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Circular Array Rotation<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 80.04%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="permutation-equation" data-attr3="code" data-attr7="20" data-attr-10="0.9" data-attr11="false" href="/challenges/permutation-equation?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Sequence Equation<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 97.41%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="jumping-on-the-clouds-revisited" data-attr3="code" data-attr7="15" data-attr-10="0.9" data-attr11="false" href="/challenges/jumping-on-the-clouds-revisited?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Jumping on the Clouds: Revisited<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 15</span><span class="success-ratio detail-item">Success Rate: 96.31%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="find-digits" data-attr3="code" data-attr7="25" data-attr-10="0.8589480334860211" data-attr11="false" href="/challenges/find-digits?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Find Digits<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 25</span><span class="success-ratio detail-item">Success Rate: 96.82%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="extra-long-factorials" data-attr3="code" data-attr7="20" data-attr-10="0.7" data-attr11="false" href="/challenges/extra-long-factorials?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Extra Long Factorials<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 95.60%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="append-and-delete" data-attr3="code" data-attr7="20" data-attr-10="0.9" data-attr11="false" href="/challenges/append-and-delete?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Append and Delete<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 68.42%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="sherlock-and-squares" data-attr3="code" data-attr7="20" data-attr-10="0.8317811408614668" data-attr11="false" href="/challenges/sherlock-and-squares?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Sherlock and Squares<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 86.46%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="library-fine" data-attr3="code" data-attr7="15" data-attr-10="0.9" data-attr11="false" href="/challenges/library-fine?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Library Fine<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 15</span><span class="success-ratio detail-item">Success Rate: 89.25%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="cut-the-sticks" data-attr3="code" data-attr7="25" data-attr-10="0.9415204678362573" data-attr11="false" href="/challenges/cut-the-sticks?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Cut the sticks<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 25</span><span class="success-ratio detail-item">Success Rate: 94.77%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="non-divisible-subset" data-attr3="code" data-attr7="20" data-attr-10="0.7" data-attr11="false" href="/challenges/non-divisible-subset?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Non-Divisible Subset<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 65.86%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="repeated-string" data-attr3="code" data-attr7="20" data-attr-10="0.9" data-attr11="false" href="/challenges/repeated-string?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Repeated String<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 90.12%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="jumping-on-the-clouds" data-attr3="code" data-attr7="20" data-attr-10="0.9" data-attr11="false" href="/challenges/jumping-on-the-clouds?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Jumping on the Clouds<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 93.91%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="equality-in-a-array" data-attr3="code" data-attr7="20" data-attr-10="0.9" data-attr11="false" href="/challenges/equality-in-a-array?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Equalize the Array<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 94.50%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="queens-attack-2" data-attr3="code" data-attr7="30" data-attr-10="0.6" data-attr11="false" href="/challenges/queens-attack-2?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Queen's Attack II<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 65.75%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="acm-icpc-team" data-attr3="code" data-attr7="25" data-attr-10="0.8439281942977824" data-attr11="false" href="/challenges/acm-icpc-team?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">ACM ICPC Team<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 25</span><span class="success-ratio detail-item">Success Rate: 88.89%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="taum-and-bday" data-attr3="code" data-attr7="25" data-attr-10="0.9" data-attr11="false" href="/challenges/taum-and-bday?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Taum and B'day<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 25</span><span class="success-ratio detail-item">Success Rate: 89.58%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="organizing-containers-of-balls" data-attr3="code" data-attr7="30" data-attr-10="0.6" data-attr11="false" href="/challenges/organizing-containers-of-balls?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Organizing Containers of Balls<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 85.21%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="encryption" data-attr3="code" data-attr7="30" data-attr-10="0.7" data-attr11="false" href="/challenges/encryption?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Encryption<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 91.84%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="bigger-is-greater" data-attr3="code" data-attr7="35" data-attr-10="0.6020131629887727" data-attr11="false" href="/challenges/bigger-is-greater?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Bigger is Greater<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 35</span><span class="success-ratio detail-item">Success Rate: 80.24%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="kaprekar-numbers" data-attr3="code" data-attr7="30" data-attr-10="0.9" data-attr11="false" href="/challenges/kaprekar-numbers?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Modified Kaprekar Numbers<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 88.69%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="beautiful-triplets" data-attr3="code" data-attr7="20" data-attr-10="0.9" data-attr11="false" href="/challenges/beautiful-triplets?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Beautiful Triplets<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 90.77%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="minimum-distances" data-attr3="code" data-attr7="20" data-attr-10="0.9" data-attr11="false" href="/challenges/minimum-distances?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Minimum Distances<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 93.51%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="halloween-sale" data-attr3="code" data-attr7="20" data-attr-10="0.9" data-attr11="false" href="/challenges/halloween-sale?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Halloween Sale<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 90.15%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="the-time-in-words" data-attr3="code" data-attr7="25" data-attr-10="0.7" data-attr11="false" href="/challenges/the-time-in-words?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">The Time in Words<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 25</span><span class="success-ratio detail-item">Success Rate: 93.19%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="chocolate-feast" data-attr3="code" data-attr7="25" data-attr-10="0.8594663138162972" data-attr11="false" href="/challenges/chocolate-feast?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Chocolate Feast <div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 25</span><span class="success-ratio detail-item">Success Rate: 91.86%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="service-lane" data-attr3="code" data-attr7="20" data-attr-10="0.9447054218046584" data-attr11="false" href="/challenges/service-lane?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Service Lane<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 97.38%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="lisa-workbook" data-attr3="code" data-attr7="25" data-attr-10="0.9" data-attr11="false" href="/challenges/lisa-workbook?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Lisa's Workbook<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 25</span><span class="success-ratio detail-item">Success Rate: 91.86%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="flatland-space-stations" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="25" data-attr-10="0.9" data-attr11="false" href="/challenges/flatland-space-stations?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Flatland Space Stations<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 25</span><span class="success-ratio detail-item">Success Rate: 80.08%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="fair-rations" data-attr3="code" data-attr7="25" data-attr-10="0.9" data-attr11="false" href="/challenges/fair-rations?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Fair Rations<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 25</span><span class="success-ratio detail-item">Success Rate: 90.42%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="cavity-map" data-attr3="code" data-attr7="30" data-attr-10="0.8698352687010532" data-attr11="false" href="/challenges/cavity-map?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Cavity Map<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 90.03%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="manasa-and-stones" data-attr3="code" data-attr7="30" data-attr-10="0.8501268157712705" data-attr11="false" href="/challenges/manasa-and-stones?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Manasa and Stones<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 90.96%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="the-grid-search" data-attr3="code" data-attr7="30" data-attr-10="0.7658227848101266" data-attr11="false" href="/challenges/the-grid-search?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">The Grid Search<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 75.41%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="happy-ladybugs" data-attr3="code" data-attr7="30" data-attr-10="0.9" data-attr11="false" href="/challenges/happy-ladybugs?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Happy Ladybugs<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 85.55%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="strange-code" data-attr3="code" data-attr7="30" data-attr-10="0.9" data-attr11="false" href="/challenges/strange-code?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Strange Counter<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 81.79%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="3d-surface-area" data-attr3="code" data-attr7="30" data-attr-10="0.6" data-attr11="false" href="/challenges/3d-surface-area?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">3D Surface Area<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 92.51%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="absolute-permutation" data-attr3="code" data-attr7="40" data-attr-10="0.7" data-attr11="false" href="/challenges/absolute-permutation?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Absolute Permutation<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 76.14%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="bomber-man" data-attr3="code" data-attr7="40" data-attr-10="0.7" data-attr11="false" href="/challenges/bomber-man?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">The Bomberman Game<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 71.12%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="two-pluses" data-attr3="code" data-attr7="40" data-attr-10="0.7" data-attr11="false" href="/challenges/two-pluses?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Ema's Supercomputer<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 65.97%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="larrys-array" data-attr3="code" data-attr7="40" data-attr-10="0.7" data-attr11="false" href="/challenges/larrys-array?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Larry's Array<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 82.19%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="almost-sorted" data-attr3="code" data-attr7="50" data-attr-10="0.7317676143386898" data-attr11="false" href="/challenges/almost-sorted?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Almost Sorted<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 73.98%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="matrix-rotation-algo" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="80" data-attr-10="0.5" data-attr11="false" href="/challenges/matrix-rotation-algo?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Matrix Layer Rotation <div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 78.40%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="big-sorting" data-attr3="code" data-attr7="20" data-attr-10="0.9" data-attr11="false" href="/challenges/big-sorting?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Big Sorting<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 64.08%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="reduced-string" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="10" data-attr-10="0.9" data-attr11="false" href="/challenges/reduced-string?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Super Reduced String<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 10</span><span class="success-ratio detail-item">Success Rate: 86.94%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="tutorial-intro" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="30" data-attr-10="0.9628593233273977" data-attr11="false" href="/challenges/tutorial-intro?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Intro to Tutorial Challenges<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 98.36%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="camelcase" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="15" data-attr-10="0.9" data-attr11="false" href="/challenges/camelcase?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">CamelCase<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 15</span><span class="success-ratio detail-item">Success Rate: 98.13%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="insertionsort1" data-attr3="code" data-attr7="30" data-attr-10="0.8380939668980245" data-attr11="false" href="/challenges/insertionsort1?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Insertion Sort - Part 1<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 87.62%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="strong-password" data-attr3="code" data-attr7="15" data-attr-10="0.9" data-attr11="false" href="/challenges/strong-password?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Strong Password<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 15</span><span class="success-ratio detail-item">Success Rate: 85.47%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="two-characters" data-attr3="code" data-attr7="20" data-attr-10="0.9" data-attr11="false" href="/challenges/two-characters?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Two Characters<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 78.58%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="insertionsort2" data-attr3="code" data-attr7="30" data-attr-10="0.9647694414853143" data-attr11="false" href="/challenges/insertionsort2?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Insertion Sort - Part 2<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 97.25%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="correctness-invariant" data-attr3="code" data-attr7="30" data-attr-10="0.9720682775437819" data-attr11="false" href="/challenges/correctness-invariant?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Correctness and the Loop Invariant<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 98.49%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="caesar-cipher-1" data-attr3="code" data-attr7="15" data-attr-10="0.9" data-attr11="false" href="/challenges/caesar-cipher-1?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Caesar Cipher<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 15</span><span class="success-ratio detail-item">Success Rate: 86.26%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="mars-exploration" data-attr3="code" data-attr7="15" data-attr-10="0.9" data-attr11="false" href="/challenges/mars-exploration?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Mars Exploration<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 15</span><span class="success-ratio detail-item">Success Rate: 94.07%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="runningtime" data-attr3="code" data-attr7="30" data-attr-10="0.9709774268875793" data-attr11="false" href="/challenges/runningtime?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Running Time of Algorithms<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 95.90%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="hackerrank-in-a-string" data-attr3="code" data-attr7="20" data-attr-10="0.9" data-attr11="false" href="/challenges/hackerrank-in-a-string?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">HackerRank in a String!<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 92.15%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="quicksort1" data-attr3="code" data-attr7="10" data-attr-10="0.931989247311828" data-attr11="false" href="/challenges/quicksort1?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Quicksort 1 - Partition<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 10</span><span class="success-ratio detail-item">Success Rate: 96.05%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="pangrams" data-attr3="code" data-attr7="20" data-attr-10="0.9088534865500131" data-attr11="false" href="/challenges/pangrams?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Pangrams<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 94.76%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="weighted-uniform-string" data-attr3="code" data-attr7="20" data-attr-10="0.9" data-attr11="false" href="/challenges/weighted-uniform-string?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Weighted Uniform Strings<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 73.98%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="separate-the-numbers" data-attr3="code" data-attr7="20" data-attr-10="0.9" data-attr11="false" href="/challenges/separate-the-numbers?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Separate the Numbers<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 89.06%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="funny-string" data-attr3="code" data-attr7="25" data-attr-10="0.9" data-attr11="false" href="/challenges/funny-string?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Funny String<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 25</span><span class="success-ratio detail-item">Success Rate: 94.53%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="countingsort1" data-attr3="code" data-attr7="30" data-attr-10="0.9418848167539267" data-attr11="false" href="/challenges/countingsort1?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Counting Sort 1<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 95.83%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="countingsort2" data-attr3="code" data-attr7="30" data-attr-10="0.9520773344302756" data-attr11="false" href="/challenges/countingsort2?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Counting Sort 2<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 97.07%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="gem-stones" data-attr3="code" data-attr7="20" data-attr-10="0.8944733990401982" data-attr11="false" href="/challenges/gem-stones?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Gemstones<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 93.45%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="alternating-characters" data-attr3="code" data-attr7="20" data-attr-10="0.9419101924447613" data-attr11="false" href="/challenges/alternating-characters?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Alternating Characters <div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 97.39%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="countingsort4" data-attr3="code" data-attr7="40" data-attr-10="0.7548298068077277" data-attr11="false" href="/challenges/countingsort4?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">The Full Counting Sort<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 83.39%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="beautiful-binary-string" data-attr3="code" data-attr7="20" data-attr-10="0.9" data-attr11="false" href="/challenges/beautiful-binary-string?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Beautiful Binary String<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 94.77%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="closest-numbers" data-attr3="code" data-attr7="35" data-attr-10="0.8160626479694045" data-attr11="false" href="/challenges/closest-numbers?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Closest Numbers<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 35</span><span class="success-ratio detail-item">Success Rate: 88.27%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="the-love-letter-mystery" data-attr3="code" data-attr7="20" data-attr-10="0.9329806829452605" data-attr11="false" href="/challenges/the-love-letter-mystery?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">The Love-Letter Mystery<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 96.83%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="find-the-median" data-attr3="code" data-attr7="35" data-attr-10="0.8047762578251797" data-attr11="false" href="/challenges/find-the-median?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Find the Median<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 35</span><span class="success-ratio detail-item">Success Rate: 90.23%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="determining-dna-health" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="50" data-attr-10="0.5" data-attr11="false" href="/challenges/determining-dna-health?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Determining DNA Health<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 29.22%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="insertion-sort" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="50" data-attr-10="0.36771381877610315" data-attr11="false" href="/challenges/insertion-sort?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Insertion Sort Advanced Analysis<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 36.01%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="palindrome-index" data-attr3="code" data-attr7="25" data-attr-10="0.9" data-attr11="false" href="/challenges/palindrome-index?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Palindrome Index<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 25</span><span class="success-ratio detail-item">Success Rate: 68.05%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="fraudulent-activity-notifications" data-attr3="code" data-attr7="40" data-attr-10="0.6" data-attr11="false" href="/challenges/fraudulent-activity-notifications?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Fraudulent Activity Notifications<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 42.78%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="anagram" data-attr3="code" data-attr7="25" data-attr-10="0.9027216856892011" data-attr11="false" href="/challenges/anagram?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Anagram<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 25</span><span class="success-ratio detail-item">Success Rate: 88.97%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="making-anagrams" data-attr3="code" data-attr7="30" data-attr-10="0.8965728274173806" data-attr11="false" href="/challenges/making-anagrams?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Making Anagrams<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 93.40%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="lilys-homework" data-attr3="code" data-attr7="40" data-attr-10="0.6" data-attr11="false" href="/challenges/lilys-homework?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Lily's Homework<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 54.07%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="game-of-thrones" data-attr3="code" data-attr7="30" data-attr-10="0.8990315403742966" data-attr11="false" href="/challenges/game-of-thrones?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Game of Thrones - I<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 93.65%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="two-strings" data-attr3="code" data-attr7="25" data-attr-10="0.9" data-attr11="false" href="/challenges/two-strings?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Two Strings<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 25</span><span class="success-ratio detail-item">Success Rate: 90.32%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="string-construction" data-attr3="code" data-attr7="25" data-attr-10="0.9" data-attr11="false" href="/challenges/string-construction?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">String Construction <div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 25</span><span class="success-ratio detail-item">Success Rate: 95.16%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="sherlock-and-valid-string" data-attr3="code" data-attr7="35" data-attr-10="0.7" data-attr11="false" href="/challenges/sherlock-and-valid-string?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Sherlock and the Valid String<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 35</span><span class="success-ratio detail-item">Success Rate: 65.52%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="richie-rich" data-attr3="code" data-attr7="30" data-attr-10="0.7" data-attr11="false" href="/challenges/richie-rich?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Highest Value Palindrome<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 54.66%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="maximum-palindromes" data-attr3="code" data-attr7="40" data-attr-10="0.6" data-attr11="false" href="/challenges/maximum-palindromes?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Maximum Palindromes<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 43.32%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="sherlock-and-anagrams" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/sherlock-and-anagrams?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Sherlock and Anagrams<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 88.50%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="common-child" data-attr3="code" data-attr7="60" data-attr-10="0.7" data-attr11="false" href="/challenges/common-child?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Common Child<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 58.65%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="bear-and-steady-gene" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/bear-and-steady-gene?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Bear and Steady Gene<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 65.76%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="morgan-and-a-string" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="100" data-attr-10="0.16957605985037408" data-attr11="false" href="/challenges/morgan-and-a-string?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Morgan and a String<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 45.35%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="count-strings" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="80" data-attr-10="0.42105263157894735" data-attr11="false" href="/challenges/count-strings?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Count Strings<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 84.66%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="string-function-calculation" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="80" data-attr-10="0.37142857142857144" data-attr11="false" href="/challenges/string-function-calculation?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">String Function Calculation<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 53.54%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="challenging-palindromes" data-attr3="code" data-attr7="80" data-attr-10="0.3" data-attr11="false" href="/challenges/challenging-palindromes?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Build a Palindrome<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 57.06%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="build-a-string" data-attr3="code" data-attr7="80" data-attr-10="0.5" data-attr11="false" href="/challenges/build-a-string?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Build a String<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 37.48%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="gridland-provinces" data-attr3="code" data-attr7="80" data-attr-10="0.5" data-attr11="false" href="/challenges/gridland-provinces?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Gridland Provinces<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 47.72%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="cards-permutation" data-attr3="code" data-attr7="85" data-attr-10="0.1" data-attr11="false" href="/challenges/cards-permutation?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Cards Permutation<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 85</span><span class="success-ratio detail-item">Success Rate: 70.06%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="ashton-and-string" data-attr3="code" data-attr7="100" data-attr-10="0.35507246376811596" data-attr11="false" href="/challenges/ashton-and-string?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Ashton and String<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 55.42%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="string-similarity" data-attr3="code" data-attr7="100" data-attr-10="0.10712011208763215" data-attr11="false" href="/challenges/string-similarity?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">String Similarity<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 35.55%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="super-functional-strings" data-attr3="code" data-attr7="80" data-attr-10="0.3" data-attr11="false" href="/challenges/super-functional-strings?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Super Functional Strings<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 53.03%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="circular-palindromes" data-attr3="code" data-attr7="120" data-attr-10="0.3" data-attr11="false" href="/challenges/circular-palindromes?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Circular Palindromes<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 120</span><span class="success-ratio detail-item">Success Rate: 59.68%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="similar-strings" data-attr3="code" data-attr7="85" data-attr-10="0.3" data-attr11="false" href="/challenges/similar-strings?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Similar Strings<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 85</span><span class="success-ratio detail-item">Success Rate: 48.17%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="save-humanity" data-attr3="code" data-attr7="100" data-attr-10="0.14361702127659576" data-attr11="false" href="/challenges/save-humanity?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Save Humanity<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 31.71%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="find-strings" data-attr3="code" data-attr7="100" data-attr-10="0.16521048451151707" data-attr11="false" href="/challenges/find-strings?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Find Strings<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 40.30%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="palindromic-border" data-attr3="code" data-attr7="100" data-attr-10="0.1" data-attr11="false" href="/challenges/palindromic-border?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Palindromic Border<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 72.89%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="two-two" data-attr3="code" data-attr7="150" data-attr-10="0.3979591836734694" data-attr11="false" href="/challenges/two-two?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Two Two<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 150</span><span class="success-ratio detail-item">Success Rate: 55.81%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="two-strings-game" data-attr3="code" data-attr7="100" data-attr-10="0.1" data-attr11="false" href="/challenges/two-strings-game?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Two Strings Game<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 79.38%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="letter-islands" data-attr3="code" data-attr7="100" data-attr-10="0.1" data-attr11="false" href="/challenges/letter-islands?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Letter Islands<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 66.49%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="pseudo-isomorphic-substrings" data-attr3="code" data-attr7="100" data-attr-10="0.1" data-attr11="false" href="/challenges/pseudo-isomorphic-substrings?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Pseudo-Isomorphic Substrings<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 72.14%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="how-many-substrings" data-attr3="code" data-attr7="100" data-attr-10="0.1" data-attr11="false" href="/challenges/how-many-substrings?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">How Many Substrings?<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 27.48%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="hackerland-radio-transmitters" data-attr3="code" data-attr7="25" data-attr-10="0.7" data-attr11="false" href="/challenges/hackerland-radio-transmitters?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Hackerland Radio Transmitters<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 25</span><span class="success-ratio detail-item">Success Rate: 65.90%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="gridland-metro" data-attr3="code" data-attr7="25" data-attr-10="0.6" data-attr11="false" href="/challenges/gridland-metro?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Gridland Metro<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 25</span><span class="success-ratio detail-item">Success Rate: 42.98%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="icecream-parlor" data-attr3="code" data-attr7="30" data-attr-10="0.9072321730314296" data-attr11="false" href="/challenges/icecream-parlor?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Ice Cream Parlor<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 92.89%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="knightl-on-chessboard" data-attr3="code" data-attr7="35" data-attr-10="0.7" data-attr11="false" href="/challenges/knightl-on-chessboard?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">KnightL on a Chessboard<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 35</span><span class="success-ratio detail-item">Success Rate: 87.01%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="minimum-loss" data-attr3="code" data-attr7="35" data-attr-10="0.6" data-attr11="false" href="/challenges/minimum-loss?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Minimum Loss<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 35</span><span class="success-ratio detail-item">Success Rate: 61.93%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="missing-numbers" data-attr3="code" data-attr7="45" data-attr-10="0.9" data-attr11="false" href="/challenges/missing-numbers?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Missing Numbers<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 45</span><span class="success-ratio detail-item">Success Rate: 83.48%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="pairs" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="50" data-attr-10="0.6471086377933705" data-attr11="false" href="/challenges/pairs?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Pairs<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 77.78%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="sherlock-and-array" data-attr3="code" data-attr7="40" data-attr-10="0.8327974276527331" data-attr11="false" href="/challenges/sherlock-and-array?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Sherlock and Array<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 81.48%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="maximum-subarray-sum" data-attr3="code" data-attr7="65" data-attr-10="0.5" data-attr11="false" href="/challenges/maximum-subarray-sum?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Maximum Subarray Sum<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 65</span><span class="success-ratio detail-item">Success Rate: 36.00%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="connected-cell-in-a-grid" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/connected-cell-in-a-grid?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Connected Cells in a Grid<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 87.25%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="short-palindrome" data-attr3="code" data-attr7="40" data-attr-10="0.7" data-attr11="false" href="/challenges/short-palindrome?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Short Palindrome<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 59.46%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="maximizing-mission-points" data-attr3="code" data-attr7="70" data-attr-10="0.5" data-attr11="false" href="/challenges/maximizing-mission-points?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Maximizing Mission Points<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 44.33%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="count-luck" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/count-luck?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Count Luck<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 86.35%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="cut-the-tree" data-attr3="code" data-attr7="50" data-attr-10="0.6666666666666666" data-attr11="false" href="/challenges/cut-the-tree?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Cut the Tree<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 70.90%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="making-candies" data-attr3="code" data-attr7="45" data-attr-10="0.5" data-attr11="false" href="/challenges/making-candies?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Making Candies<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 45</span><span class="success-ratio detail-item">Success Rate: 59.06%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="gena" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/gena?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Gena Playing Hanoi<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 69.10%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="xor-quadruples" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/xor-quadruples?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Beautiful Quadruples<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 49.63%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="red-knights-shortest-path" data-attr3="code" data-attr7="60" data-attr-10="0.6" data-attr11="false" href="/challenges/red-knights-shortest-path?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Red Knight's Shortest Path<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 83.29%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="bike-racers" data-attr3="code" data-attr7="65" data-attr-10="0.4065040650406504" data-attr11="false" href="/challenges/bike-racers?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Bike Racers<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 65</span><span class="success-ratio detail-item">Success Rate: 47.21%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="task-scheduling" data-attr3="code" data-attr7="70" data-attr-10="0.35231895850284783" data-attr11="false" href="/challenges/task-scheduling?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Task Scheduling <div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 49.86%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="similarpair" data-attr3="code" data-attr7="70" data-attr-10="0.3948220064724919" data-attr11="false" href="/challenges/similarpair?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Similar Pair<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 45.91%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="playing-with-numbers" data-attr3="code" data-attr7="70" data-attr-10="0.5" data-attr11="false" href="/challenges/playing-with-numbers?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Absolute Element Sums<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 31.57%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="almost-integer-rock-garden" data-attr3="code" data-attr7="80" data-attr-10="0.1" data-attr11="false" href="/challenges/almost-integer-rock-garden?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Almost Integer Rock Garden<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 82.08%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="sorted-subsegments" data-attr3="code" data-attr7="80" data-attr-10="0.5" data-attr11="false" href="/challenges/sorted-subsegments?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Sorted Subsegments<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 33.16%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="distant-pairs" data-attr3="code" data-attr7="80" data-attr-10="0.1" data-attr11="false" href="/challenges/distant-pairs?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Distant Pairs<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 58.69%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="king-richards-knights" data-attr3="code" data-attr7="80" data-attr-10="0.5" data-attr11="false" href="/challenges/king-richards-knights?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">King Richard's Knights<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 62.60%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="frog-in-maze" data-attr3="code" data-attr7="65" data-attr-10="0.5" data-attr11="false" href="/challenges/frog-in-maze?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Frog in Maze<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 65</span><span class="success-ratio detail-item">Success Rate: 46.32%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="torque-and-development" data-attr3="code" data-attr7="30" data-attr-10="0.7" data-attr11="false" href="/challenges/torque-and-development?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Roads and Libraries<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 65.78%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="journey-to-the-moon" data-attr3="code" data-attr7="50" data-attr-10="0.6280068728522337" data-attr11="false" href="/challenges/journey-to-the-moon?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Journey to the Moon<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 62.62%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="synchronous-shopping" data-attr3="code" data-attr7="40" data-attr-10="0.7" data-attr11="false" href="/challenges/synchronous-shopping?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Synchronous Shopping<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 60.06%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="subset-component" data-attr3="code" data-attr7="50" data-attr-10="0.49074074074074076" data-attr11="false" href="/challenges/subset-component?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Subset Component<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 67.86%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="bfsshortreach" data-attr3="code" data-attr7="55" data-attr-10="0.7" data-attr11="false" href="/challenges/bfsshortreach?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Breadth First Search: Shortest Reach<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 55</span><span class="success-ratio detail-item">Success Rate: 78.28%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="kruskalmstrsub" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/kruskalmstrsub?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Kruskal (MST): Really Special Subtree<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 84.04%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="even-tree" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/even-tree?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Even Tree<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 89.09%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="the-quickest-way-up" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/the-quickest-way-up?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Snakes and Ladders: The Quickest Way Up<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 78.67%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="dijkstrashortreach" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="60" data-attr-10="0.5" data-attr11="false" href="/challenges/dijkstrashortreach?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Dijkstra: Shortest Reach 2<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 55.93%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="the-story-of-a-tree" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/the-story-of-a-tree?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">The Story of a Tree<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 54.21%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="primsmstsub" data-attr3="code" data-attr7="60" data-attr-10="0.7" data-attr11="false" href="/challenges/primsmstsub?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Prim's (MST) : Special Subtree<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 84.01%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="toll-cost-digits" data-attr3="code" data-attr7="60" data-attr-10="0.5" data-attr11="false" href="/challenges/toll-cost-digits?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Toll Cost Digits<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 65.19%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="real-estate-broker" data-attr3="code" data-attr7="60" data-attr-10="0.5" data-attr11="false" href="/challenges/real-estate-broker?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Real Estate Broker<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 61.23%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="clique" data-attr3="code" data-attr7="60" data-attr-10="0.6723646723646723" data-attr11="false" href="/challenges/clique?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Clique<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 62.65%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="beautiful-path" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/beautiful-path?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Minimum Penalty Path<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 53.26%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="borrowing-money" data-attr3="code" data-attr7="50" data-attr-10="0.5" data-attr11="false" href="/challenges/borrowing-money?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Demanding Money<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 56.17%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="value-of-friendship" data-attr3="code" data-attr7="55" data-attr-10="0.5" data-attr11="false" href="/challenges/value-of-friendship?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">The Value of Friendship<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 55</span><span class="success-ratio detail-item">Success Rate: 59.84%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="coprime-paths" data-attr3="code" data-attr7="80" data-attr-10="0.1" data-attr11="false" href="/challenges/coprime-paths?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Coprime Paths<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 75.54%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="minimum-mst-graph" data-attr3="code" data-attr7="80" data-attr-10="0.1" data-attr11="false" href="/challenges/minimum-mst-graph?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Minimum MST Graph<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 70.56%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="jack-goes-to-rapture" data-attr3="code" data-attr7="80" data-attr-10="0.625" data-attr11="false" href="/challenges/jack-goes-to-rapture?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Jack goes to Rapture <div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 65.24%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="crab-graphs" data-attr3="code" data-attr7="50" data-attr-10="0.651685393258427" data-attr11="false" href="/challenges/crab-graphs?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Crab Graphs<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 81.88%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="beadornaments" data-attr3="code" data-attr7="70" data-attr-10="0.3" data-attr11="false" href="/challenges/beadornaments?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Bead Ornaments<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 87.16%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="jeanies-route" data-attr3="code" data-attr7="80" data-attr-10="0.7" data-attr11="false" href="/challenges/jeanies-route?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Jeanie's Route<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 74.98%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="floyd-city-of-blinding-lights" data-attr3="code" data-attr7="75" data-attr-10="0.5" data-attr11="false" href="/challenges/floyd-city-of-blinding-lights?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Floyd : City of Blinding Lights<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 75</span><span class="success-ratio detail-item">Success Rate: 81.88%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="johnland" data-attr3="code" data-attr7="60" data-attr-10="0.7" data-attr11="false" href="/challenges/johnland?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Roads in HackerLand<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 50.87%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="kingdom-connectivity" data-attr3="code" data-attr7="75" data-attr-10="0.45951283739302173" data-attr11="false" href="/challenges/kingdom-connectivity?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Kingdom Connectivity<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 75</span><span class="success-ratio detail-item">Success Rate: 59.40%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="computer-game" data-attr3="code" data-attr7="80" data-attr-10="0.5135135135135135" data-attr11="false" href="/challenges/computer-game?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Computer Game<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 37.89%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="rust-murderer" data-attr3="code" data-attr7="70" data-attr-10="0.7" data-attr11="false" href="/challenges/rust-murderer?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Rust &amp; Murderer<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 62.37%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="problem-solving" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="80" data-attr-10="0.515625" data-attr11="false" href="/challenges/problem-solving?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Problem solving<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 23.40%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="journey-scheduling" data-attr3="code" data-attr7="75" data-attr-10="0.5" data-attr11="false" href="/challenges/journey-scheduling?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Journey Scheduling<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 75</span><span class="success-ratio detail-item">Success Rate: 75.62%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="matrix" data-attr3="code" data-attr7="70" data-attr-10="0.5970695970695971" data-attr11="false" href="/challenges/matrix?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Matrix<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 65.09%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="episode-recording" data-attr3="code" data-attr7="70" data-attr-10="0.5" data-attr11="false" href="/challenges/episode-recording?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Recording Episodes<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 71.96%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="repair-roads" data-attr3="code" data-attr7="80" data-attr-10="0.4857142857142857" data-attr11="false" href="/challenges/repair-roads?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Repair Roads<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 59.01%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="kth-ancestor" data-attr3="code" data-attr7="90" data-attr-10="0.43529411764705883" data-attr11="false" href="/challenges/kth-ancestor?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Kth Ancestor<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 90</span><span class="success-ratio detail-item">Success Rate: 59.44%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="bytelandian-tours" data-attr3="code" data-attr7="90" data-attr-10="0.5851851851851851" data-attr11="false" href="/challenges/bytelandian-tours?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">ByteLandian Tours<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 90</span><span class="success-ratio detail-item">Success Rate: 75.16%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="shortest-path" data-attr3="code" data-attr7="75" data-attr-10="0.5" data-attr11="false" href="/challenges/shortest-path?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Find the Path<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 75</span><span class="success-ratio detail-item">Success Rate: 52.64%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="savita-and-friends" data-attr3="code" data-attr7="90" data-attr-10="0.5" data-attr11="false" href="/challenges/savita-and-friends?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Savita And Friends<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 90</span><span class="success-ratio detail-item">Success Rate: 83.55%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="liars" data-attr3="code" data-attr7="85" data-attr-10="0.3813559322033898" data-attr11="false" href="/challenges/liars?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Liars<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 85</span><span class="success-ratio detail-item">Success Rate: 72.39%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="jumping-rooks" data-attr3="code" data-attr7="80" data-attr-10="0.3" data-attr11="false" href="/challenges/jumping-rooks?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Jumping Rooks<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 73.12%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="tripartite-matching" data-attr3="code" data-attr7="80" data-attr-10="0.5" data-attr11="false" href="/challenges/tripartite-matching?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Tripartite Matching<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 63.80%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="tree-flow" data-attr3="code" data-attr7="80" data-attr-10="0.5" data-attr11="false" href="/challenges/tree-flow?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Tree Flow<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 59.18%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="dag-queries" data-attr3="code" data-attr7="80" data-attr-10="0.1" data-attr11="false" href="/challenges/dag-queries?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">DAG Queries<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 38.51%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="favourite-sequence" data-attr3="code" data-attr7="95" data-attr-10="0.36507936507936506" data-attr11="false" href="/challenges/favourite-sequence?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Favorite sequence<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 95</span><span class="success-ratio detail-item">Success Rate: 53.99%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="cat-jogging" data-attr3="code" data-attr7="80" data-attr-10="0.3" data-attr11="false" href="/challenges/cat-jogging?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Jogging Cats<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 56.13%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="quadrant-queries" data-attr3="code" data-attr7="100" data-attr-10="0.2502596053997923" data-attr11="false" href="/challenges/quadrant-queries?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Quadrant Queries<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 44.35%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="hacker-country" data-attr3="code" data-attr7="100" data-attr-10="0.5333333333333333" data-attr11="false" href="/challenges/hacker-country?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Hacker Country<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 63.55%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="missile-defend" data-attr3="code" data-attr7="100" data-attr-10="0.5384615384615384" data-attr11="false" href="/challenges/missile-defend?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">HackerX<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 62.38%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="huarongdao" data-attr3="code" data-attr7="100" data-attr-10="0.125" data-attr11="false" href="/challenges/huarongdao?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Huarongdao<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 63.83%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="training-the-army" data-attr3="code" data-attr7="120" data-attr-10="0.5454545454545454" data-attr11="false" href="/challenges/training-the-army?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Training the army<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 120</span><span class="success-ratio detail-item">Success Rate: 81.52%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="jim-and-his-lan-party" data-attr3="code" data-attr7="80" data-attr-10="0.5" data-attr11="false" href="/challenges/jim-and-his-lan-party?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Jim and his LAN Party<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 68.51%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="travel-in-hackerland" data-attr3="code" data-attr7="80" data-attr-10="0.5" data-attr11="false" href="/challenges/travel-in-hackerland?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Travel in HackerLand<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 71.45%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="alex-vs-fedor" data-attr3="code" data-attr7="150" data-attr-10="0.1" data-attr11="false" href="/challenges/alex-vs-fedor?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Alex vs Fedor<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 150</span><span class="success-ratio detail-item">Success Rate: 84.25%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="vertical-paths" data-attr3="code" data-attr7="100" data-attr-10="0.1" data-attr11="false" href="/challenges/vertical-paths?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Vertical Paths<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 89.21%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="drive" data-attr3="code" data-attr7="90" data-attr-10="0.1" data-attr11="false" href="/challenges/drive?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Drive<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 90</span><span class="success-ratio detail-item">Success Rate: 69.42%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="tsp-grid" data-attr3="code" data-attr7="100" data-attr-10="0.1" data-attr11="false" href="/challenges/tsp-grid?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Travelling Salesman in a Grid<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 53.45%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="road-network" data-attr3="code" data-attr7="90" data-attr-10="0.1" data-attr11="false" href="/challenges/road-network?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Road Network<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 90</span><span class="success-ratio detail-item">Success Rate: 74.84%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="going-office" data-attr3="code" data-attr7="100" data-attr-10="0.1839863713798978" data-attr11="false" href="/challenges/going-office?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Going to the Office<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 47.98%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="tree-splitting" data-attr3="code" data-attr7="100" data-attr-10="0.3" data-attr11="false" href="/challenges/tree-splitting?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Tree Splitting<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 76.96%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="ticket" data-attr3="code" data-attr7="100" data-attr-10="0.1" data-attr11="false" href="/challenges/ticket?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Ticket<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 65.56%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="dfs-edges" data-attr3="code" data-attr7="100" data-attr-10="0.1" data-attr11="false" href="/challenges/dfs-edges?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">DFS Edges<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 82.67%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="diameter-minimization" data-attr3="code" data-attr7="100" data-attr-10="0.1" data-attr11="false" href="/challenges/diameter-minimization?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Diameter Minimization<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 77.23%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="airports" data-attr3="code" data-attr7="100" data-attr-10="0.1" data-attr11="false" href="/challenges/airports?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Airports<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 83.97%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="definite-random-walks" data-attr3="code" data-attr7="100" data-attr-10="0.1" data-attr11="false" href="/challenges/definite-random-walks?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Definite Random Walks<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 85.23%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="minimum-absolute-difference-in-an-array" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="15" data-attr-10="0.9" data-attr11="false" href="/challenges/minimum-absolute-difference-in-an-array?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Minimum Absolute Difference in an Array<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 15</span><span class="success-ratio detail-item">Success Rate: 86.74%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="marcs-cakewalk" data-attr3="code" data-attr7="15" data-attr-10="0.9" data-attr11="false" href="/challenges/marcs-cakewalk?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Marc's Cakewalk<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 15</span><span class="success-ratio detail-item">Success Rate: 96.34%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="grid-challenge" data-attr3="code" data-attr7="20" data-attr-10="0.9" data-attr11="false" href="/challenges/grid-challenge?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Grid Challenge<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 83.68%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="luck-balance" data-attr3="code" data-attr7="20" data-attr-10="0.9" data-attr11="false" href="/challenges/luck-balance?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Luck Balance<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 93.02%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="maximum-perimeter-triangle" data-attr3="code" data-attr7="20" data-attr-10="0.9" data-attr11="false" href="/challenges/maximum-perimeter-triangle?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Maximum Perimeter Triangle<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 90.87%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="beautiful-pairs" data-attr3="code" data-attr7="30" data-attr-10="0.9" data-attr11="false" href="/challenges/beautiful-pairs?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Beautiful Pairs<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 75.87%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="candies" data-attr3="code" data-attr7="50" data-attr-10="0.7514746362563901" data-attr11="false" href="/challenges/candies?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Candies<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 67.48%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="sherlock-and-the-beast" data-attr3="code" data-attr7="30" data-attr-10="0.8173509561304837" data-attr11="false" href="/challenges/sherlock-and-the-beast?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Sherlock and The Beast<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 82.51%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="priyanka-and-toys" data-attr3="code" data-attr7="30" data-attr-10="0.8421985815602837" data-attr11="false" href="/challenges/priyanka-and-toys?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Priyanka and Toys<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 91.84%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="largest-permutation" data-attr3="code" data-attr7="30" data-attr-10="0.9" data-attr11="false" href="/challenges/largest-permutation?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Largest Permutation<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 61.95%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="mark-and-toys" data-attr3="code" data-attr7="35" data-attr-10="0.8835942818243703" data-attr11="false" href="/challenges/mark-and-toys?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Mark and Toys<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 35</span><span class="success-ratio detail-item">Success Rate: 93.61%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="greedy-florist" data-attr3="code" data-attr7="35" data-attr-10="0.7" data-attr11="false" href="/challenges/greedy-florist?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Greedy Florist<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 35</span><span class="success-ratio detail-item">Success Rate: 93.88%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="angry-children" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="35" data-attr-10="0.7751615308151093" data-attr11="false" href="/challenges/angry-children?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Max Min<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 35</span><span class="success-ratio detail-item">Success Rate: 85.47%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="jim-and-the-orders" data-attr3="code" data-attr7="40" data-attr-10="0.9" data-attr11="false" href="/challenges/jim-and-the-orders?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Jim and the Orders<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 88.49%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="two-arrays" data-attr3="code" data-attr7="40" data-attr-10="0.8715039577836412" data-attr11="false" href="/challenges/two-arrays?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Permuting Two Arrays<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 94.31%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="board-cutting" data-attr3="code" data-attr7="60" data-attr-10="0.5" data-attr11="false" href="/challenges/board-cutting?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Cutting Boards<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 75.74%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="reverse-shuffle-merge" data-attr3="code" data-attr7="50" data-attr-10="0.37209302325581395" data-attr11="false" href="/challenges/reverse-shuffle-merge?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Reverse Shuffle Merge<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 54.45%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="pylons" data-attr3="code" data-attr7="40" data-attr-10="0.7" data-attr11="false" href="/challenges/pylons?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Goodland Electricity<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 69.36%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="cloudy-day" data-attr3="code" data-attr7="45" data-attr-10="0.7" data-attr11="false" href="/challenges/cloudy-day?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Cloudy Day <div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 45</span><span class="success-ratio detail-item">Success Rate: 37.57%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="chief-hopper" data-attr3="code" data-attr7="65" data-attr-10="0.5882352941176471" data-attr11="false" href="/challenges/chief-hopper?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Chief Hopper<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 65</span><span class="success-ratio detail-item">Success Rate: 77.02%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="sherlock-and-minimax" data-attr3="code" data-attr7="70" data-attr-10="0.5414364640883977" data-attr11="false" href="/challenges/sherlock-and-minimax?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Sherlock and MiniMax<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 52.84%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="accessory-collection" data-attr3="code" data-attr7="60" data-attr-10="0.5" data-attr11="false" href="/challenges/accessory-collection?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Accessory Collection<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 41.41%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="team-formation" data-attr3="code" data-attr7="70" data-attr-10="0.2018348623853211" data-attr11="false" href="/challenges/team-formation?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Team Formation<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 40.33%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="fighting-pits" data-attr3="code" data-attr7="80" data-attr-10="0.5" data-attr11="false" href="/challenges/fighting-pits?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Fighting Pits<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 49.69%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="lena-sort" data-attr3="code" data-attr7="30" data-attr-10="0.6" data-attr11="false" href="/challenges/lena-sort?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Lena Sort<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 53.60%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="coin-change" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="60" data-attr-10="0.7" data-attr11="false" href="/challenges/coin-change?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">The Coin Change Problem<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 79.45%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="equal" data-attr3="code" data-attr7="30" data-attr-10="0.7" data-attr11="false" href="/challenges/equal?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Equal<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 53.73%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="flipping-the-matrix" data-attr3="code" data-attr7="30" data-attr-10="0.65" data-attr11="false" href="/challenges/flipping-the-matrix?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Flipping the Matrix<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 90.60%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="sherlock-and-cost" data-attr3="code" data-attr7="50" data-attr-10="0.7424593967517401" data-attr11="false" href="/challenges/sherlock-and-cost?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Sherlock and Cost<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 67.09%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="an-interesting-game-1" data-attr3="code" data-attr7="35" data-attr-10="0.7" data-attr11="false" href="/challenges/an-interesting-game-1?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Gaming Array<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 35</span><span class="success-ratio detail-item">Success Rate: 76.01%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="new-year-chaos" data-attr3="code" data-attr7="40" data-attr-10="0.7" data-attr11="false" href="/challenges/new-year-chaos?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">New Year Chaos<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 66.99%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="construct-the-array" data-attr3="code" data-attr7="35" data-attr-10="0.7" data-attr11="false" href="/challenges/construct-the-array?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Construct the Array<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 35</span><span class="success-ratio detail-item">Success Rate: 65.59%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="bonetrousle" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/bonetrousle?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Bonetrousle<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 47.82%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="kingdom-division" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/kingdom-division?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Kingdom Division<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 57.03%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="kmp-problem" data-attr3="code" data-attr7="60" data-attr-10="0.5" data-attr11="false" href="/challenges/kmp-problem?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Yet Another KMP Problem<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 62.55%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="sam-and-substrings" data-attr3="code" data-attr7="40" data-attr-10="0.6787878787878788" data-attr11="false" href="/challenges/sam-and-substrings?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Sam and substrings<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 58.25%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="beautiful-3-set" data-attr3="code" data-attr7="60" data-attr-10="0.5" data-attr11="false" href="/challenges/beautiful-3-set?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Beautiful 3 Set<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 55.62%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="fibonacci-modified" data-attr3="code" data-attr7="45" data-attr-10="0.7299546142208775" data-attr11="false" href="/challenges/fibonacci-modified?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Fibonacci Modified<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 45</span><span class="success-ratio detail-item">Success Rate: 80.86%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="inverse-rmq" data-attr3="code" data-attr7="60" data-attr-10="0.5" data-attr11="false" href="/challenges/inverse-rmq?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Inverse RMQ<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 68.62%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="abbr" data-attr3="code" data-attr7="40" data-attr-10="0.7" data-attr11="false" href="/challenges/abbr?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Abbreviation<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 44.35%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="two-subarrays" data-attr3="code" data-attr7="70" data-attr-10="0.1" data-attr11="false" href="/challenges/two-subarrays?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Two Subarrays<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 56.12%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="prime-xor" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/prime-xor?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Prime XOR<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 54.09%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="lovely-triplets" data-attr3="code" data-attr7="80" data-attr-10="0.3" data-attr11="false" href="/challenges/lovely-triplets?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Lovely Triplets<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 78.45%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="array-construction" data-attr3="code" data-attr7="80" data-attr-10="0.3" data-attr11="false" href="/challenges/array-construction?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Array Construction<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 60.04%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="decibinary-numbers" data-attr3="code" data-attr7="60" data-attr-10="0.5" data-attr11="false" href="/challenges/decibinary-numbers?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Decibinary Numbers<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 54.98%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="fair-cut" data-attr3="code" data-attr7="40" data-attr-10="0.7" data-attr11="false" href="/challenges/fair-cut?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Fair Cut<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 55.53%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="maxsubarray" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/maxsubarray?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">The Maximum Subarray<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 76.39%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="angry-children-2" data-attr3="code" data-attr7="50" data-attr-10="0.5328947368421053" data-attr11="false" href="/challenges/angry-children-2?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Angry Children 2<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 47.61%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="sherlocks-array-merging-algorithm" data-attr3="code" data-attr7="60" data-attr-10="0.5" data-attr11="false" href="/challenges/sherlocks-array-merging-algorithm?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Sherlock's Array Merging Algorithm<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 70.56%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="prime-digit-sums" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/prime-digit-sums?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Prime Digit Sums<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 48.71%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="hr-city" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/hr-city?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">HackerRank City<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 78.71%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="summing-pieces" data-attr3="code" data-attr7="40" data-attr-10="0.7" data-attr11="false" href="/challenges/summing-pieces?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Summing Pieces<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 58.66%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="mr-k-marsh" data-attr3="code" data-attr7="40" data-attr-10="0.7" data-attr11="false" href="/challenges/mr-k-marsh?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Mr K marsh<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 51.03%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="substring-diff" data-attr3="code" data-attr7="60" data-attr-10="0.6001348617666892" data-attr11="false" href="/challenges/substring-diff?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Substring Diff<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 66.67%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="xor-and-sum" data-attr3="code" data-attr7="50" data-attr-10="0.7745901639344263" data-attr11="false" href="/challenges/xor-and-sum?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Xor and Sum<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 84.65%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="lego-blocks" data-attr3="code" data-attr7="50" data-attr-10="0.72564302416212" data-attr11="false" href="/challenges/lego-blocks?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Lego Blocks<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 75.11%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="brick-tiling" data-attr3="code" data-attr7="60" data-attr-10="0.5169491525423728" data-attr11="false" href="/challenges/brick-tiling?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Brick Tiling<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 71.75%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="alien-languages" data-attr3="code" data-attr7="60" data-attr-10="0.5647058823529412" data-attr11="false" href="/challenges/alien-languages?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Alien Languages<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 65.66%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="stockmax" data-attr3="code" data-attr7="50" data-attr-10="0.788421297372704" data-attr11="false" href="/challenges/stockmax?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Stock Maximize<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 82.23%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="two-robots" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/two-robots?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Two Robots<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 49.34%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="cuttree" data-attr3="code" data-attr7="40" data-attr-10="0.6153846153846154" data-attr11="false" href="/challenges/cuttree?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Cut Tree<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 61.41%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="taras-beautiful-permutations" data-attr3="code" data-attr7="70" data-attr-10="0.5" data-attr11="false" href="/challenges/taras-beautiful-permutations?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Tara's Beautiful Permutations<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 68.81%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="wet-shark-and-two-subsequences" data-attr3="code" data-attr7="80" data-attr-10="0.7" data-attr11="false" href="/challenges/wet-shark-and-two-subsequences?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Wet Shark and Two Subsequences<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 56.92%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="array-splitting" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/array-splitting?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Nikita and the Game<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 60.80%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="choosing-white-balls" data-attr3="code" data-attr7="60" data-attr-10="0.5" data-attr11="false" href="/challenges/choosing-white-balls?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Choosing White Balls<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 56.16%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="mandragora" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/mandragora?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Mandragora Forest<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 73.14%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="red-john-is-back" data-attr3="code" data-attr7="65" data-attr-10="0.7826523777628935" data-attr11="false" href="/challenges/red-john-is-back?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Red John is Back<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 65</span><span class="success-ratio detail-item">Success Rate: 79.77%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="tutzki-and-lcs" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/tutzki-and-lcs?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">LCS Returns<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 42.53%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="grid-walking" data-attr3="code" data-attr7="55" data-attr-10="0.6150234741784038" data-attr11="false" href="/challenges/grid-walking?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Grid Walking<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 55</span><span class="success-ratio detail-item">Success Rate: 50.17%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="matrix-land" data-attr3="code" data-attr7="55" data-attr-10="0.5" data-attr11="false" href="/challenges/matrix-land?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Matrix Land<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 55</span><span class="success-ratio detail-item">Success Rate: 70.18%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="unbounded-knapsack" data-attr3="code" data-attr7="60" data-attr-10="0.7814207650273224" data-attr11="false" href="/challenges/unbounded-knapsack?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Knapsack<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 81.07%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="play-game" data-attr3="code" data-attr7="55" data-attr-10="0.7749510763209393" data-attr11="false" href="/challenges/play-game?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Bricks Game<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 55</span><span class="success-ratio detail-item">Success Rate: 78.12%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="longest-increasing-subsequent" data-attr3="code" data-attr7="60" data-attr-10="0.3920099875156055" data-attr11="false" href="/challenges/longest-increasing-subsequent?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">The Longest Increasing Subsequence<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 41.56%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="coin-on-the-table" data-attr3="code" data-attr7="65" data-attr-10="0.6299126637554585" data-attr11="false" href="/challenges/coin-on-the-table?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Coin on the Table<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 65</span><span class="success-ratio detail-item">Success Rate: 71.11%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="dynamic-programming-classics-the-longest-common-subsequence" data-attr3="code" data-attr7="55" data-attr-10="0.7" data-attr11="false" href="/challenges/dynamic-programming-classics-the-longest-common-subsequence?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">The Longest Common Subsequence<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 55</span><span class="success-ratio detail-item">Success Rate: 62.34%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="strplay" data-attr3="code" data-attr7="65" data-attr-10="0.7113821138211383" data-attr11="false" href="/challenges/strplay?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Play with words<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 65</span><span class="success-ratio detail-item">Success Rate: 71.79%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="black-n-white-tree-1" data-attr3="code" data-attr7="80" data-attr-10="0.5" data-attr11="false" href="/challenges/black-n-white-tree-1?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Black and White Tree<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 68.34%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="counting-special-sub-cubes" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/counting-special-sub-cubes?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Counting Special Sub-Cubes<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 73.02%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="interval-selection" data-attr3="code" data-attr7="65" data-attr-10="0.6081967213114754" data-attr11="false" href="/challenges/interval-selection?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Interval Selection<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 65</span><span class="success-ratio detail-item">Success Rate: 66.13%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="string-reduction" data-attr3="code" data-attr7="70" data-attr-10="0.5636407885130202" data-attr11="false" href="/challenges/string-reduction?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">String Reduction<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 57.08%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="far-vertices" data-attr3="code" data-attr7="70" data-attr-10="0.5589041095890411" data-attr11="false" href="/challenges/far-vertices?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Far Vertices<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 66.72%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="counting-road-networks" data-attr3="code" data-attr7="90" data-attr-10="0.1" data-attr11="false" href="/challenges/counting-road-networks?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Counting Road Networks<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 90</span><span class="success-ratio detail-item">Success Rate: 72.65%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="superman-celebrates-diwali" data-attr3="code" data-attr7="80" data-attr-10="0.5" data-attr11="false" href="/challenges/superman-celebrates-diwali?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Superman Celebrates Diwali <div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 75.97%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="hexagonal-grid" data-attr3="code" data-attr7="70" data-attr-10="0.5" data-attr11="false" href="/challenges/hexagonal-grid?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Hexagonal Grid<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 79.49%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="queens-on-board" data-attr3="code" data-attr7="70" data-attr-10="0.49246231155778897" data-attr11="false" href="/challenges/queens-on-board?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Queens on Board<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 67.32%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="shashank-and-palindromic-strings" data-attr3="code" data-attr7="60" data-attr-10="0.3" data-attr11="false" href="/challenges/shashank-and-palindromic-strings?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Shashank and the Palindromic Strings<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 76.62%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="points-in-a-plane" data-attr3="code" data-attr7="80" data-attr-10="0.37538461538461537" data-attr11="false" href="/challenges/points-in-a-plane?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Points in a Plane<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 59.15%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="turn-off-the-lights" data-attr3="code" data-attr7="70" data-attr-10="0.5" data-attr11="false" href="/challenges/turn-off-the-lights?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Turn Off the Lights<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 63.56%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="animal-transport" data-attr3="code" data-attr7="70" data-attr-10="0.5" data-attr11="false" href="/challenges/animal-transport?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Animal Transport<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 85.08%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="the-indian-job" data-attr3="code" data-attr7="70" data-attr-10="0.6153846153846154" data-attr11="false" href="/challenges/the-indian-job?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">The Indian Job<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 55.54%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="requirement" data-attr3="code" data-attr7="80" data-attr-10="0.3628048780487805" data-attr11="false" href="/challenges/requirement?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Requirement<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 55.26%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="a-super-hero" data-attr3="code" data-attr7="80" data-attr-10="0.5" data-attr11="false" href="/challenges/a-super-hero?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">A Super Hero<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 58.94%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="clues-on-a-binary-path" data-attr3="code" data-attr7="60" data-attr-10="0.5" data-attr11="false" href="/challenges/clues-on-a-binary-path?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Clues on a Binary Path<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 22.56%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="road-maintenance" data-attr3="code" data-attr7="100" data-attr-10="0.5" data-attr11="false" href="/challenges/road-maintenance?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Road Maintenance<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 69.51%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="billboards" data-attr3="code" data-attr7="80" data-attr-10="0.3434029320302088" data-attr11="false" href="/challenges/billboards?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Billboards<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 38.72%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="beautiful-string" data-attr3="code" data-attr7="80" data-attr-10="0.5" data-attr11="false" href="/challenges/beautiful-string?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Beautiful Strings<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 35.92%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="covering-the-stains" data-attr3="code" data-attr7="80" data-attr-10="0.5" data-attr11="false" href="/challenges/covering-the-stains?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Covering the stains<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 73.34%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="gcd-matrix" data-attr3="code" data-attr7="60" data-attr-10="0.5" data-attr11="false" href="/challenges/gcd-matrix?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">GCD Matrix<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 50.51%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="fairy-chess" data-attr3="code" data-attr7="80" data-attr-10="0.39845758354755784" data-attr11="false" href="/challenges/fairy-chess?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Fairy Chess<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 62.09%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="suffix-rotation" data-attr3="code" data-attr7="80" data-attr-10="0.1" data-attr11="false" href="/challenges/suffix-rotation?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Suffix Rotation<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 55.60%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="newyear-present" data-attr3="code" data-attr7="80" data-attr-10="0.5" data-attr11="false" href="/challenges/newyear-present?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">New Year Present<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 47.75%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="travel-around-the-world" data-attr3="code" data-attr7="120" data-attr-10="0.6280487804878049" data-attr11="false" href="/challenges/travel-around-the-world?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Travel around the world<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 120</span><span class="success-ratio detail-item">Success Rate: 52.49%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="longest-palindromic-subsequence" data-attr3="code" data-attr7="70" data-attr-10="0.5" data-attr11="false" href="/challenges/longest-palindromic-subsequence?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Longest Palindromic Subsequence<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 50.14%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="candles-2" data-attr3="code" data-attr7="85" data-attr-10="0.7" data-attr11="false" href="/challenges/candles-2?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Candles Counting<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 85</span><span class="success-ratio detail-item">Success Rate: 44.32%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="hyper-strings" data-attr3="code" data-attr7="90" data-attr-10="0.3409436834094368" data-attr11="false" href="/challenges/hyper-strings?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Hyper Strings<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 90</span><span class="success-ratio detail-item">Success Rate: 43.36%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="swappermutation" data-attr3="code" data-attr7="85" data-attr-10="0.696969696969697" data-attr11="false" href="/challenges/swappermutation?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Swap Permutation<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 85</span><span class="success-ratio detail-item">Success Rate: 61.02%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="extremum-permutations" data-attr3="code" data-attr7="100" data-attr-10="0.7352941176470589" data-attr11="false" href="/challenges/extremum-permutations?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Extremum Permutations<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 72.55%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="square-subsequences" data-attr3="code" data-attr7="90" data-attr-10="0.41567291311754684" data-attr11="false" href="/challenges/square-subsequences?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Square Subsequences<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 90</span><span class="success-ratio detail-item">Success Rate: 59.97%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="dorsey-thief" data-attr3="code" data-attr7="85" data-attr-10="0.3651685393258427" data-attr11="false" href="/challenges/dorsey-thief?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Dorsey Thief<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 85</span><span class="success-ratio detail-item">Success Rate: 47.54%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="mining" data-attr3="code" data-attr7="75" data-attr-10="0.3" data-attr11="false" href="/challenges/mining?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Mining<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 75</span><span class="success-ratio detail-item">Success Rate: 59.21%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="police-operation" data-attr3="code" data-attr7="100" data-attr-10="0.4857142857142857" data-attr11="false" href="/challenges/police-operation?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Police Operation<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 58.57%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="zurikela" data-attr3="code" data-attr7="80" data-attr-10="0.5" data-attr11="false" href="/challenges/zurikela?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Zurikela's Graph<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 85.69%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="modify-the-sequence" data-attr3="code" data-attr7="100" data-attr-10="0.325" data-attr11="false" href="/challenges/modify-the-sequence?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Modify The Sequence<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 27.13%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="longest-mod-path" data-attr3="code" data-attr7="80" data-attr-10="0.5" data-attr11="false" href="/challenges/longest-mod-path?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Longest Mod Path<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 80.14%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="p-sequences" data-attr3="code" data-attr7="100" data-attr-10="0.550561797752809" data-attr11="false" href="/challenges/p-sequences?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">P-sequences<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 56.59%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="robot" data-attr3="code" data-attr7="120" data-attr-10="0.36363636363636365" data-attr11="false" href="/challenges/robot?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Robot<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 120</span><span class="success-ratio detail-item">Success Rate: 51.86%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="lucky-numbers" data-attr3="code" data-attr7="100" data-attr-10="0.1718972895863053" data-attr11="false" href="/challenges/lucky-numbers?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Lucky Numbers<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 23.12%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="unfair-game" data-attr3="code" data-attr7="100" data-attr-10="0.3105263157894737" data-attr11="false" href="/challenges/unfair-game?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Unfair Game<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 58.30%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="oil-well" data-attr3="code" data-attr7="100" data-attr-10="0.547945205479452" data-attr11="false" href="/challenges/oil-well?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Oil Well<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 53.82%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="find-the-seed" data-attr3="code" data-attr7="100" data-attr-10="0.3" data-attr11="false" href="/challenges/find-the-seed?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Find the Seed<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 57.05%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="the-blacklist" data-attr3="code" data-attr7="100" data-attr-10="0.3" data-attr11="false" href="/challenges/the-blacklist?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">The Blacklist<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 60.20%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="tree-pruning" data-attr3="code" data-attr7="100" data-attr-10="0.3111111111111111" data-attr11="false" href="/challenges/tree-pruning?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Tree Pruning<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 61.91%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="ones-and-twos" data-attr3="code" data-attr7="100" data-attr-10="0.5454545454545454" data-attr11="false" href="/challenges/ones-and-twos?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Ones and Twos<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 53.72%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="count-scorecards" data-attr3="code" data-attr7="100" data-attr-10="0.15839243498817968" data-attr11="false" href="/challenges/count-scorecards?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Count Scorecards<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 50.24%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="vim-war" data-attr3="code" data-attr7="120" data-attr-10="0.3" data-attr11="false" href="/challenges/vim-war?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Vim War<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 120</span><span class="success-ratio detail-item">Success Rate: 64.77%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="best-spot" data-attr3="code" data-attr7="100" data-attr-10="0.3" data-attr11="false" href="/challenges/best-spot?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Best spot<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 50.82%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="divisible-numbers" data-attr3="code" data-attr7="100" data-attr-10="0.1" data-attr11="false" href="/challenges/divisible-numbers?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Divisible Numbers<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 21.26%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="unique-divide-and-conquer" data-attr3="code" data-attr7="90" data-attr-10="0.3" data-attr11="false" href="/challenges/unique-divide-and-conquer?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Unique Divide And Conquer       <div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 90</span><span class="success-ratio detail-item">Success Rate: 64.62%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="happy-king" data-attr3="code" data-attr7="100" data-attr-10="0.1" data-attr11="false" href="/challenges/happy-king?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">King and Four Sons<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 67.78%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="dortmund-dilemma" data-attr3="code" data-attr7="150" data-attr-10="0.3" data-attr11="false" href="/challenges/dortmund-dilemma?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Dortmund Dilemma<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 150</span><span class="success-ratio detail-item">Success Rate: 81.97%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="super-kth-lis" data-attr3="code" data-attr7="90" data-attr-10="0.3" data-attr11="false" href="/challenges/super-kth-lis?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Super Kth LIS<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 90</span><span class="success-ratio detail-item">Success Rate: 65.98%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="count-ways-1" data-attr3="code" data-attr7="100" data-attr-10="0.1" data-attr11="false" href="/challenges/count-ways-1?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Counting the Ways<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 53.02%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="hard-drive-disks" data-attr3="code" data-attr7="100" data-attr-10="0.1" data-attr11="false" href="/challenges/hard-drive-disks?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Hard Disk Drives<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 64.91%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="separate-the-chocolate" data-attr3="code" data-attr7="250" data-attr-10="0.1" data-attr11="false" href="/challenges/separate-the-chocolate?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Separate the chocolate<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 250</span><span class="success-ratio detail-item">Success Rate: 69.45%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="lonely-integer" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="20" data-attr-10="0.9" data-attr11="false" href="/challenges/lonely-integer?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Lonely Integer<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 96.73%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="maximizing-xor" data-attr3="code" data-attr7="30" data-attr-10="0.9" data-attr11="false" href="/challenges/maximizing-xor?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Maximizing XOR<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 97.00%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="counter-game" data-attr3="code" data-attr7="30" data-attr-10="0.7" data-attr11="false" href="/challenges/counter-game?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Counter game<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 69.94%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="xor-se" data-attr3="code" data-attr7="40" data-attr-10="0.7" data-attr11="false" href="/challenges/xor-se?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Xor-sequence<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 53.84%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="sum-vs-xor" data-attr3="code" data-attr7="25" data-attr-10="0.9" data-attr11="false" href="/challenges/sum-vs-xor?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Sum vs XOR<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 25</span><span class="success-ratio detail-item">Success Rate: 67.76%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="the-great-xor" data-attr3="code" data-attr7="25" data-attr-10="0.7" data-attr11="false" href="/challenges/the-great-xor?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">The Great XOR<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 25</span><span class="success-ratio detail-item">Success Rate: 70.30%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="flipping-bits" data-attr3="code" data-attr7="40" data-attr-10="0.8955243644067796" data-attr11="false" href="/challenges/flipping-bits?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Flipping bits<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 96.40%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="yet-another-minimax-problem" data-attr3="code" data-attr7="30" data-attr-10="0.7" data-attr11="false" href="/challenges/yet-another-minimax-problem?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Yet Another Minimax Problem<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 39.77%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="sansa-and-xor" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="30" data-attr-10="0.7356426618049225" data-attr11="false" href="/challenges/sansa-and-xor?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Sansa and XOR<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 83.99%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="and-product" data-attr3="code" data-attr7="40" data-attr-10="0.6197183098591549" data-attr11="false" href="/challenges/and-product?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">AND Product<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 57.14%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="winning-lottery-ticket" data-attr3="code" data-attr7="40" data-attr-10="0.6" data-attr11="false" href="/challenges/winning-lottery-ticket?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Winning Lottery Ticket<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 54.01%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="xoring-ninja" data-attr3="code" data-attr7="55" data-attr-10="0.4924078091106291" data-attr11="false" href="/challenges/xoring-ninja?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Xoring Ninja<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 55</span><span class="success-ratio detail-item">Success Rate: 59.46%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="cipher" data-attr3="code" data-attr7="50" data-attr-10="0.6790606653620352" data-attr11="false" href="/challenges/cipher?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Cipher<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 74.40%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="xor-matrix" data-attr3="code" data-attr7="50" data-attr-10="0.5" data-attr11="false" href="/challenges/xor-matrix?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">XOR Matrix<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 34.45%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="whats-next" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/whats-next?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">What's Next?<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 47.78%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="string-transmission" data-attr3="code" data-attr7="60" data-attr-10="0.4876543209876543" data-attr11="false" href="/challenges/string-transmission?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">String Transmission<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 61.89%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="aorb" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/aorb?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">A or B<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 71.89%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="manipulative-numbers" data-attr3="code" data-attr7="55" data-attr-10="0.4776357827476038" data-attr11="false" href="/challenges/manipulative-numbers?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Manipulative Numbers<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 55</span><span class="success-ratio detail-item">Success Rate: 50.88%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="stonegame" data-attr3="code" data-attr7="70" data-attr-10="0.4609375" data-attr11="false" href="/challenges/stonegame?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Stone Game<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 60.00%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="2s-complement" data-attr3="code" data-attr7="70" data-attr-10="0.38971583220568334" data-attr11="false" href="/challenges/2s-complement?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">2's complement<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 42.73%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="changing-bits" data-attr3="code" data-attr7="70" data-attr-10="0.29770992366412213" data-attr11="false" href="/challenges/changing-bits?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Changing Bits<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 44.19%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="xor-key" data-attr3="code" data-attr7="80" data-attr-10="0.22768762677484786" data-attr11="false" href="/challenges/xor-key?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">XOR key<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 27.88%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="maximizing-the-function" data-attr3="code" data-attr7="70" data-attr-10="0.5" data-attr11="false" href="/challenges/maximizing-the-function?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Maximizing the Function <div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 65.49%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="xor-subsequence" data-attr3="code" data-attr7="80" data-attr-10="0.27586206896551724" data-attr11="false" href="/challenges/xor-subsequence?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">XOR Subsequences<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 47.06%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="iterate-it" data-attr3="code" data-attr7="90" data-attr-10="0.1" data-attr11="false" href="/challenges/iterate-it?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Iterate It<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 90</span><span class="success-ratio detail-item">Success Rate: 28.40%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="hamming-distance" data-attr3="code" data-attr7="150" data-attr-10="0.1" data-attr11="false" href="/challenges/hamming-distance?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Hamming Distance<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 150</span><span class="success-ratio detail-item">Success Rate: 51.23%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="pmix" data-attr3="code" data-attr7="80" data-attr-10="0.42105263157894735" data-attr11="false" href="/challenges/pmix?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Mixing proteins<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 47.75%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="the-power-sum" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="20" data-attr-10="0.7" data-attr11="false" href="/challenges/the-power-sum?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">The Power Sum<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 89.16%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="crossword-puzzle" data-attr3="code" data-attr7="30" data-attr-10="0.7" data-attr11="false" href="/challenges/crossword-puzzle?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Crossword Puzzle<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 82.25%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="recursive-digit-sum" data-attr3="code" data-attr7="30" data-attr-10="0.773972602739726" data-attr11="false" href="/challenges/recursive-digit-sum?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Recursive Digit Sum<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 72.91%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="simplified-chess-engine" data-attr3="code" data-attr7="40" data-attr-10="0.7" data-attr11="false" href="/challenges/simplified-chess-engine?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Simplified Chess Engine<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 61.97%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="password-cracker" data-attr3="code" data-attr7="40" data-attr-10="0.7" data-attr11="false" href="/challenges/password-cracker?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Password Cracker<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 40.27%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="arithmetic-expressions" data-attr3="code" data-attr7="40" data-attr-10="0.5" data-attr11="false" href="/challenges/arithmetic-expressions?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Arithmetic Expressions<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 42.74%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="stone-division-2" data-attr3="code" data-attr7="50" data-attr-10="0.6" data-attr11="false" href="/challenges/stone-division-2?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title"> Stone Division, Revisited<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 59.04%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="k-factorization" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="50" data-attr-10="0.5" data-attr11="false" href="/challenges/k-factorization?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">K Factorization<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 78.40%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="bowling-pins" data-attr3="code" data-attr7="60" data-attr-10="0.5" data-attr11="false" href="/challenges/bowling-pins?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Bowling Pins<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 44.22%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="simplified-chess-engine-ii" data-attr3="code" data-attr7="60" data-attr-10="0.5" data-attr11="false" href="/challenges/simplified-chess-engine-ii?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Simplified Chess Engine II<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 70.17%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="repeat-k-sums" data-attr3="code" data-attr7="150" data-attr-10="0.3" data-attr11="false" href="/challenges/repeat-k-sums?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Repetitive K-Sums<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 150</span><span class="success-ratio detail-item">Success Rate: 66.91%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="game-of-stones-1" data-attr3="code" data-attr7="15" data-attr-10="0.9" data-attr11="false" href="/challenges/game-of-stones-1?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Game of Stones<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 15</span><span class="success-ratio detail-item">Success Rate: 87.93%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="tower-breakers-1" data-attr3="code" data-attr7="15" data-attr-10="0.9" data-attr11="false" href="/challenges/tower-breakers-1?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Tower Breakers <div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 15</span><span class="success-ratio detail-item">Success Rate: 88.14%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="a-chessboard-game-1" data-attr3="code" data-attr7="15" data-attr-10="0.9" data-attr11="false" href="/challenges/a-chessboard-game-1?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">A Chessboard Game<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="max-score detail-item">Max Score: 15</span><span class="success-ratio detail-item">Success Rate: 89.48%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="nim-game-1" data-attr3="code" data-attr7="15" data-attr-10="0.9" data-attr11="false" href="/challenges/nim-game-1?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Introduction to Nim Game<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="max-score detail-item">Max Score: 15</span><span class="success-ratio detail-item">Success Rate: 84.75%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="misere-nim-1" data-attr3="code" data-attr7="20" data-attr-10="0.9" data-attr11="false" href="/challenges/misere-nim-1?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Misère Nim<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 79.17%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="nimble-game-1" data-attr3="code" data-attr7="20" data-attr-10="0.9" data-attr11="false" href="/challenges/nimble-game-1?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Nimble Game<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 70.70%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="alice-and-bobs-silly-game" data-attr3="code" data-attr7="30" data-attr-10="0.7" data-attr11="false" href="/challenges/alice-and-bobs-silly-game?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Alice and Bob's Silly Game<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 71.00%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="poker-nim-1" data-attr3="code" data-attr7="20" data-attr-10="0.9" data-attr11="false" href="/challenges/poker-nim-1?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Poker Nim<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 86.64%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="tower-breakers-revisited-1" data-attr3="code" data-attr7="25" data-attr-10="0.7" data-attr11="false" href="/challenges/tower-breakers-revisited-1?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Tower Breakers, Revisited!<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 25</span><span class="success-ratio detail-item">Success Rate: 57.71%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="tower-breakers-again-1" data-attr3="code" data-attr7="30" data-attr-10="0.7" data-attr11="false" href="/challenges/tower-breakers-again-1?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Tower Breakers, Again!<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 57.73%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="zero-move-nim" data-attr3="code" data-attr7="50" data-attr-10="0.6" data-attr11="false" href="/challenges/zero-move-nim?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Zero-Move Nim<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 65.73%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="chessboard-game-again-1" data-attr3="code" data-attr7="30" data-attr-10="0.7" data-attr11="false" href="/challenges/chessboard-game-again-1?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Chessboard Game, Again!<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 69.61%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="digits-square-board-1" data-attr3="code" data-attr7="35" data-attr-10="0.7" data-attr11="false" href="/challenges/digits-square-board-1?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Digits Square Board<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 35</span><span class="success-ratio detail-item">Success Rate: 65.50%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="fun-game-1" data-attr3="code" data-attr7="40" data-attr-10="0.7" data-attr11="false" href="/challenges/fun-game-1?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Fun Game<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 56.23%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="stone-division" data-attr3="code" data-attr7="50" data-attr-10="0.5" data-attr11="false" href="/challenges/stone-division?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Stone Division<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 46.04%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="chocolate-in-box" data-attr3="code" data-attr7="70" data-attr-10="0.6940298507462687" data-attr11="false" href="/challenges/chocolate-in-box?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Chocolate in Box<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 75.68%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="kitty-and-katty" data-attr3="code" data-attr7="80" data-attr-10="0.7" data-attr11="false" href="/challenges/kitty-and-katty?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Kitty and Katty<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 77.77%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="powers-game-1" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/powers-game-1?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Powers Game<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 74.73%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="deforestation-1" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/deforestation-1?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Deforestation<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 62.53%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="bob-and-ben" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/bob-and-ben?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Bob and Ben<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 82.32%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="tower-breakers-the-final-battle-1" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/tower-breakers-the-final-battle-1?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Tower Breakers - The Final Battle<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 66.82%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="simple-game" data-attr3="code" data-attr7="60" data-attr-10="0.5" data-attr11="false" href="/challenges/simple-game?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Simple Game<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 61.11%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="permutation-game" data-attr3="code" data-attr7="70" data-attr-10="0.7418817651956703" data-attr11="false" href="/challenges/permutation-game?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Permutation game<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 71.88%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="move-the-coins" data-attr3="code" data-attr7="60" data-attr-10="0.5" data-attr11="false" href="/challenges/move-the-coins?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Move the Coins<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 77.64%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="benders-play" data-attr3="code" data-attr7="70" data-attr-10="0.7567567567567568" data-attr11="false" href="/challenges/benders-play?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Play on benders<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 76.85%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="newyear-game" data-attr3="code" data-attr7="60" data-attr-10="0.7" data-attr11="false" href="/challenges/newyear-game?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">New Year Game<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 59.95%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="stone-piles" data-attr3="code" data-attr7="85" data-attr-10="0.5776805251641138" data-attr11="false" href="/challenges/stone-piles?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Stone Piles<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 85</span><span class="success-ratio detail-item">Success Rate: 66.06%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="chocolate-game" data-attr3="code" data-attr7="90" data-attr-10="0.4878048780487805" data-attr11="false" href="/challenges/chocolate-game?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Chocolate Game<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 90</span><span class="success-ratio detail-item">Success Rate: 50.86%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="the-prime-game" data-attr3="code" data-attr7="90" data-attr-10="0.5" data-attr11="false" href="/challenges/the-prime-game?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">The Prime Game <div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 90</span><span class="success-ratio detail-item">Success Rate: 69.97%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="vertical-rooks" data-attr3="code" data-attr7="90" data-attr-10="0.684931506849315" data-attr11="false" href="/challenges/vertical-rooks?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Vertical Rooks<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 90</span><span class="success-ratio detail-item">Success Rate: 75.63%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="half" data-attr3="code" data-attr7="90" data-attr-10="0.7261904761904762" data-attr11="false" href="/challenges/half?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">A stones game<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 90</span><span class="success-ratio detail-item">Success Rate: 74.01%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="taste-of-win" data-attr3="code" data-attr7="100" data-attr-10="0.1" data-attr11="false" href="/challenges/taste-of-win?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Tastes Like Winning<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 49.92%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="walking-the-approximate-longest-path" data-attr3="code" data-attr7="70" data-attr-10="0.5" data-attr11="false" href="/challenges/walking-the-approximate-longest-path?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Walking the Approximate Longest Path<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 77.70%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="sams-puzzle" data-attr3="code" data-attr7="85" data-attr-10="0.3" data-attr11="false" href="/challenges/sams-puzzle?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Sam's Puzzle (Approximate)<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 85</span><span class="success-ratio detail-item">Success Rate: 65.04%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="spies-revised" data-attr3="code" data-attr7="100" data-attr-10="0.01624815361890694" data-attr11="false" href="/challenges/spies-revised?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Spies, Revised<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 2.69%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="tbsp" data-attr3="code" data-attr7="100" data-attr-10="0.003484320557491289" data-attr11="false" href="/challenges/tbsp?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">TBS Problem<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 5.46%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="prime-date" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="40" data-attr-10="0.6" data-attr11="false" href="/challenges/prime-date?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Prime Dates<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 82.46%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="minimum-operations" data-attr3="code" data-attr7="45" data-attr-10="0.7" data-attr11="false" href="/challenges/minimum-operations?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Minimum Operations<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 45</span><span class="success-ratio detail-item">Success Rate: 66.18%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="strings-xor" data-attr3="code" data-attr7="25" data-attr-10="0.9" data-attr11="false" href="/challenges/strings-xor?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">XOR Strings<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 25</span><span class="success-ratio detail-item">Success Rate: 93.86%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="zig-zag-sequence" data-attr3="code" data-attr7="40" data-attr-10="0.6" data-attr11="false" href="/challenges/zig-zag-sequence?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Zig Zag Sequence<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 90.04%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="smart-number" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="25" data-attr-10="0.9" data-attr11="false" href="/challenges/smart-number?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Smart Number<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 25</span><span class="success-ratio detail-item">Success Rate: 84.79%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a></div></div></section>'''
soup_algo_problems = BeautifulSoup(algo_problems_html, "html.parser")
problems_rows_html = soup_algo_problems.find_all(class_ = "js-track-click challenge-list-item")
print(f'\n --------- There are {len(problems_rows_html)} algo problems --------- \n')
for problem_html in problems_rows_html:
    problem = problem_html["data-attr1"]
    # Get number of pages in leaderboard
    page_lead_html = r.get(f'https://www.hackerrank.com/challenges/{problem}/leaderboard?limit=100',headers=header).text
    soup_lead = BeautifulSoup(page_lead_html, "html.parser")
    no_pages = int(soup_lead.find_all("a", {"class":"pagination-button"})[-2].text)
    algo_no_pages = algo_no_pages +  no_pages 
    alog_list.append(problem)
    # Get problem info
    difficulty = problem_html.find(class_ = "difficulty").text
    max_score = problem_html.find(class_ = "max-score").text.split(": ")[1]
    try:
        skills = problem_html.find(class_ = "skill detail-item").text.split("(")[1][:-1]
    except: 
        skills = "Null"
    print(f'algorithms,{problem},{difficulty},{skills},{max_score} ({no_pages} pages)')

print(f'\n --------- There are total {algo_no_pages} pages --------- \n')
# Out:
#  --------- There are 442 algo problems ---------
#
# algorithms,day-of-the-programmer,Easy,Basic,15 (2624 pages)
# algorithms,solve-me-first,Easy,Basic,1 (41419 pages)
# algorithms,simple-array-sum,Easy,Basic,10 (22203 pages)
# algorithms,compare-the-triplets,Easy,Basic,10 (16298 pages)
# algorithms,a-very-big-sum,Easy,Basic,10 (16902 pages)
# algorithms,diagonal-difference,Easy,Basic,10 (13758 pages)
# algorithms,plus-minus,Easy,Basic,10 (12578 pages)
# algorithms,staircase,Easy,Basic,10 (12148 pages)
# algorithms,mini-max-sum,Easy,Basic,10 (10477 pages)
# algorithms,birthday-cake-candles,Easy,Basic,10 (9664 pages)
# algorithms,time-conversion,Easy,Basic,15 (9272 pages)
# algorithms,grading,Easy,Basic,10 (6798 pages)
# algorithms,apple-and-orange,Easy,Basic,10 (5727 pages)
# algorithms,kangaroo,Easy,Basic,10 (5745 pages)
# algorithms,between-two-sets,Easy,Basic,10 (3158 pages)
# algorithms,breaking-best-and-worst-records,Easy,Basic,10 (4051 pages)
# ...

# %%
ds_list = []
ds_no_pages = 0
# Getting all data structures problems details
ds_problems_html = '''<section class="list-container left-pane"><div class="recommended-challenge pjB"><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="dynamic-array" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="15" data-attr-10="0.9" data-attr11="false" href="/challenges/dynamic-array?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Dynamic Array<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 15</span><span class="success-ratio detail-item">Success Rate: 85.90%</span></div></h4></div></div></header><div class="preview-box"><div class="preview-content">Learn to use dynamic arrays by solving this problem.</div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></div></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a></div><div><div class="challenges-list"><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="arrays-ds" data-attr3="code" data-attr4="true" data-attr5="true" data-attr7="10" data-attr-10="0.9" data-attr11="false" href="/challenges/arrays-ds?isFullScreen=true"><div class="single-item challenges-list-view-v2 first-challenge cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Arrays - DS<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 10</span><span class="success-ratio detail-item">Success Rate: 94.11%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content has-icon align-icon-right"><span class="ui-text" aria-hidden="false">Solved</span><i class="ui-icon-check-circle ui-btn-icon"></i></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="2d-array" data-attr3="code" data-attr4="true" data-attr5="true" data-attr7="15" data-attr-10="0.9" data-attr11="false" href="/challenges/2d-array?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">2D Array - DS<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 15</span><span class="success-ratio detail-item">Success Rate: 93.18%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content has-icon align-icon-right"><span class="ui-text" aria-hidden="false">Solved</span><i class="ui-icon-check-circle ui-btn-icon"></i></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="array-left-rotation" data-attr3="code" data-attr4="true" data-attr5="true" data-attr7="20" data-attr-10="0.9" data-attr11="false" href="/challenges/array-left-rotation?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Left Rotation<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 90.48%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content has-icon align-icon-right"><span class="ui-text" aria-hidden="false">Solved</span><i class="ui-icon-check-circle ui-btn-icon"></i></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a href="https://www.hackerrank.com/dtcc-gracehopper-codeathon" rel="noopener noreferrer" target="_blank" class="challenge-list-item promo-challenge-list-item"><div class="single-item challenges-list-view-v2 cursor"><div class="individual-challenge-card-v2 content--list-v2 track_content" style="background-color: rgb(0, 150, 214);"><div class="content--list_body"><div class="promo-content"><header class="content--list_header-v2"><div class="challenge-name-details "><h4 class="challengecard-title" style="color: rgb(0, 0, 0);">DTCC Grace Hopper<div class="card-details" style="color: rgb(0, 0, 0);">DTCC CODE-A-THON on 14th Oct'22 on HackerRank</div></h4></div><div class="cta-container"><div class="ctas"><img src="https://hr-assets.s3.amazonaws.com/contests/2153b032-ac13-4035-9919-88f0f6d92035/dtcc.png" alt="DTCC logo" class="promo-icon branding-promo-logo"></div></div></header></div></div></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="sparse-arrays" data-attr3="code" data-attr4="true" data-attr5="true" data-attr7="25" data-attr-10="0.7" data-attr11="false" href="/challenges/sparse-arrays?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Sparse Arrays<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 25</span><span class="success-ratio detail-item">Success Rate: 97.35%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content has-icon align-icon-right"><span class="ui-text" aria-hidden="false">Solved</span><i class="ui-icon-check-circle ui-btn-icon"></i></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="crush" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="60" data-attr-10="0.5048025613660619" data-attr11="false" href="/challenges/crush?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Array Manipulation<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 59.28%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="print-the-elements-of-a-linked-list" data-attr3="code" data-attr7="5" data-attr-10="0.9692106736331405" data-attr11="false" href="/challenges/print-the-elements-of-a-linked-list?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Print the Elements of a Linked List<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 5</span><span class="success-ratio detail-item">Success Rate: 97.30%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="insert-a-node-at-the-tail-of-a-linked-list" data-attr3="code" data-attr7="5" data-attr-10="0.9846815372211771" data-attr11="false" href="/challenges/insert-a-node-at-the-tail-of-a-linked-list?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Insert a Node at the Tail of a Linked List<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 5</span><span class="success-ratio detail-item">Success Rate: 95.24%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="insert-a-node-at-the-head-of-a-linked-list" data-attr3="code" data-attr7="5" data-attr-10="0.9867938371239912" data-attr11="false" href="/challenges/insert-a-node-at-the-head-of-a-linked-list?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Insert a node at the head of a linked list<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 5</span><span class="success-ratio detail-item">Success Rate: 98.47%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="insert-a-node-at-a-specific-position-in-a-linked-list" data-attr3="code" data-attr7="5" data-attr-10="0.9808102345415778" data-attr11="false" href="/challenges/insert-a-node-at-a-specific-position-in-a-linked-list?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Insert a node at a specific position in a linked list<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 5</span><span class="success-ratio detail-item">Success Rate: 97.11%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="delete-a-node-from-a-linked-list" data-attr3="code" data-attr7="5" data-attr-10="0.9872489639783233" data-attr11="false" href="/challenges/delete-a-node-from-a-linked-list?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Delete a Node<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 5</span><span class="success-ratio detail-item">Success Rate: 95.55%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="print-the-elements-of-a-linked-list-in-reverse" data-attr3="code" data-attr7="5" data-attr-10="0.9714188499489622" data-attr11="false" href="/challenges/print-the-elements-of-a-linked-list-in-reverse?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Print in Reverse<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 5</span><span class="success-ratio detail-item">Success Rate: 98.15%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="reverse-a-linked-list" data-attr3="code" data-attr7="5" data-attr-10="0.9778679454075987" data-attr11="false" href="/challenges/reverse-a-linked-list?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Reverse a linked list<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 5</span><span class="success-ratio detail-item">Success Rate: 98.05%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="compare-two-linked-lists" data-attr3="code" data-attr7="5" data-attr-10="0.987905604719764" data-attr11="false" href="/challenges/compare-two-linked-lists?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Compare two linked lists<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 5</span><span class="success-ratio detail-item">Success Rate: 98.56%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="merge-two-sorted-linked-lists" data-attr3="code" data-attr7="5" data-attr-10="0.9782713664896185" data-attr11="false" href="/challenges/merge-two-sorted-linked-lists?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Merge two sorted linked lists<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 5</span><span class="success-ratio detail-item">Success Rate: 93.92%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="get-the-value-of-the-node-at-a-specific-position-from-the-tail" data-attr3="code" data-attr7="5" data-attr-10="0.9859922178988327" data-attr11="false" href="/challenges/get-the-value-of-the-node-at-a-specific-position-from-the-tail?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Get Node Value<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 5</span><span class="success-ratio detail-item">Success Rate: 98.43%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="delete-duplicate-value-nodes-from-a-sorted-linked-list" data-attr3="code" data-attr7="5" data-attr-10="0.9876753081172971" data-attr11="false" href="/challenges/delete-duplicate-value-nodes-from-a-sorted-linked-list?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Delete duplicate-value nodes from a sorted linked list<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 5</span><span class="success-ratio detail-item">Success Rate: 97.58%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="detect-whether-a-linked-list-contains-a-cycle" data-attr3="code" data-attr7="5" data-attr-10="0.7" data-attr11="false" href="/challenges/detect-whether-a-linked-list-contains-a-cycle?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Cycle Detection<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 5</span><span class="success-ratio detail-item">Success Rate: 92.80%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="find-the-merge-point-of-two-joined-linked-lists" data-attr3="code" data-attr7="5" data-attr-10="0.9809310151430174" data-attr11="false" href="/challenges/find-the-merge-point-of-two-joined-linked-lists?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Find Merge Point of Two Lists<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Basic)</span><span class="max-score detail-item">Max Score: 5</span><span class="success-ratio detail-item">Success Rate: 92.57%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="insert-a-node-into-a-sorted-doubly-linked-list" data-attr3="code" data-attr7="5" data-attr-10="0.9522776572668112" data-attr11="false" href="/challenges/insert-a-node-into-a-sorted-doubly-linked-list?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Inserting a Node Into a Sorted Doubly Linked List<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 5</span><span class="success-ratio detail-item">Success Rate: 92.77%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="reverse-a-doubly-linked-list" data-attr3="code" data-attr7="5" data-attr-10="0.9731081926203877" data-attr11="false" href="/challenges/reverse-a-doubly-linked-list?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Reverse a doubly linked list<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 5</span><span class="success-ratio detail-item">Success Rate: 97.26%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="tree-preorder-traversal" data-attr3="code" data-attr7="10" data-attr-10="0.9" data-attr11="false" href="/challenges/tree-preorder-traversal?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Tree: Preorder Traversal<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 10</span><span class="success-ratio detail-item">Success Rate: 98.56%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="tree-postorder-traversal" data-attr3="code" data-attr7="10" data-attr-10="0.9" data-attr11="false" href="/challenges/tree-postorder-traversal?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Tree: Postorder Traversal<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 10</span><span class="success-ratio detail-item">Success Rate: 99.49%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="tree-inorder-traversal" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="10" data-attr-10="0.9" data-attr11="false" href="/challenges/tree-inorder-traversal?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Tree: Inorder Traversal<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 10</span><span class="success-ratio detail-item">Success Rate: 99.57%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="tree-height-of-a-binary-tree" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="10" data-attr-10="0.9" data-attr11="false" href="/challenges/tree-height-of-a-binary-tree?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Tree: Height of a Binary Tree<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 10</span><span class="success-ratio detail-item">Success Rate: 96.75%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="tree-top-view" data-attr3="code" data-attr7="20" data-attr-10="0.9" data-attr11="false" href="/challenges/tree-top-view?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Tree : Top View<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 61.20%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="tree-level-order-traversal" data-attr3="code" data-attr7="20" data-attr-10="0.9" data-attr11="false" href="/challenges/tree-level-order-traversal?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Tree: Level Order Traversal<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 96.54%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="binary-search-tree-insertion" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="20" data-attr-10="0.9" data-attr11="false" href="/challenges/binary-search-tree-insertion?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Binary Search Tree : Insertion<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 95.91%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="tree-huffman-decoding" data-attr3="code" data-attr7="20" data-attr-10="0.7" data-attr11="false" href="/challenges/tree-huffman-decoding?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Tree: Huffman Decoding <div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 97.87%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="binary-search-tree-lowest-common-ancestor" data-attr3="code" data-attr7="30" data-attr-10="0.9" data-attr11="false" href="/challenges/binary-search-tree-lowest-common-ancestor?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Binary Search Tree : Lowest Common Ancestor<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 93.20%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="swap-nodes-algo" data-attr3="code" data-attr7="40" data-attr-10="0.7" data-attr11="false" href="/challenges/swap-nodes-algo?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Swap Nodes [Algo]<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 88.67%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="kittys-calculations-on-a-tree" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="80" data-attr-10="0.3" data-attr11="false" href="/challenges/kittys-calculations-on-a-tree?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Kitty's Calculations on a Tree<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 57.72%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="is-binary-search-tree" data-attr3="code" data-attr7="30" data-attr-10="0.6" data-attr11="false" href="/challenges/is-binary-search-tree?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Is This a Binary Search Tree?<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 75.05%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="square-ten-tree" data-attr3="code" data-attr7="60" data-attr-10="0.5" data-attr11="false" href="/challenges/square-ten-tree?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Square-Ten Tree<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 80.29%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="balanced-forest" data-attr3="code" data-attr7="60" data-attr-10="0.5" data-attr11="false" href="/challenges/balanced-forest?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Balanced Forest<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 69.05%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="jenny-subtrees" data-attr3="code" data-attr7="70" data-attr-10="0.5" data-attr11="false" href="/challenges/jenny-subtrees?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Jenny's Subtrees<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 81.09%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="tree-coordinates" data-attr3="code" data-attr7="100" data-attr-10="0.1" data-attr11="false" href="/challenges/tree-coordinates?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Tree Coordinates<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 53.68%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="array-pairs" data-attr3="code" data-attr7="100" data-attr-10="0.3" data-attr11="false" href="/challenges/array-pairs?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Array Pairs<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 11.04%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="self-balancing-tree" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/self-balancing-tree?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Self Balancing Tree<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 81.59%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="array-and-simple-queries" data-attr3="code" data-attr7="80" data-attr-10="0.5" data-attr11="false" href="/challenges/array-and-simple-queries?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Array and simple queries<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 42.81%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="median" data-attr3="code" data-attr7="70" data-attr-10="0.418013856812933" data-attr11="false" href="/challenges/median?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Median Updates<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 55.01%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="merging-communities" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="50" data-attr-10="0.5" data-attr11="false" href="/challenges/merging-communities?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Merging Communities <div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 77.39%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="qheap1" data-attr3="code" data-attr4="false" data-attr5="false" data-attr7="25" data-attr-10="0.9" data-attr11="false" href="/challenges/qheap1?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">QHEAP1<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 25</span><span class="success-ratio detail-item">Success Rate: 68.37%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="maximum-element" data-attr3="code" data-attr7="20" data-attr-10="0.9" data-attr11="false" href="/challenges/maximum-element?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Maximum Element<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 20</span><span class="success-ratio detail-item">Success Rate: 71.91%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="queue-using-two-stacks" data-attr3="code" data-attr7="30" data-attr-10="0.6" data-attr11="false" href="/challenges/queue-using-two-stacks?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Queue using Two Stacks<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 89.63%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="components-in-graph" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/components-in-graph?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Components in a graph<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 87.87%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="balanced-brackets" data-attr3="code" data-attr7="25" data-attr-10="0.7" data-attr11="false" href="/challenges/balanced-brackets?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Balanced Brackets<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 25</span><span class="success-ratio detail-item">Success Rate: 86.91%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="castle-on-the-grid" data-attr3="code" data-attr7="30" data-attr-10="0.7" data-attr11="false" href="/challenges/castle-on-the-grid?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Castle on the Grid<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 72.76%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="jesse-and-cookies" data-attr3="code" data-attr7="25" data-attr-10="0.9" data-attr11="false" href="/challenges/jesse-and-cookies?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Jesse and Cookies<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 25</span><span class="success-ratio detail-item">Success Rate: 68.05%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="kundu-and-tree" data-attr3="code" data-attr7="80" data-attr-10="0.4658385093167702" data-attr11="false" href="/challenges/kundu-and-tree?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Kundu and Tree<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 85.86%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="find-the-running-median" data-attr3="code" data-attr7="50" data-attr-10="0.5" data-attr11="false" href="/challenges/find-the-running-median?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Find the Running Median<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 73.76%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="down-to-zero-ii" data-attr3="code" data-attr7="40" data-attr-10="0.7" data-attr11="false" href="/challenges/down-to-zero-ii?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Down to Zero II<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 48.80%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="equal-stacks" data-attr3="code" data-attr7="25" data-attr-10="0.9" data-attr11="false" href="/challenges/equal-stacks?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Equal Stacks<div class="card-details pmT"><span class="difficulty easy detail-item">Easy</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 25</span><span class="success-ratio detail-item">Success Rate: 80.20%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="minimum-average-waiting-time" data-attr3="code" data-attr7="80" data-attr-10="0.4182692307692308" data-attr11="false" href="/challenges/minimum-average-waiting-time?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Minimum Average Waiting Time<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 62.97%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="truck-tour" data-attr3="code" data-attr7="50" data-attr-10="0.5" data-attr11="false" href="/challenges/truck-tour?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Truck Tour<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 84.87%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="game-of-two-stacks" data-attr3="code" data-attr7="30" data-attr-10="0.6" data-attr11="false" href="/challenges/game-of-two-stacks?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Game of Two Stacks<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 45.24%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="largest-rectangle" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/largest-rectangle?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Largest Rectangle <div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 70.98%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="queries-with-fixed-length" data-attr3="code" data-attr7="50" data-attr-10="0.5" data-attr11="false" href="/challenges/queries-with-fixed-length?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Queries with Fixed Length<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 68.06%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="maximum-cost-queries" data-attr3="code" data-attr7="60" data-attr-10="0.5" data-attr11="false" href="/challenges/maximum-cost-queries?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Super Maximum Cost Queries<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 87.04%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="simple-text-editor" data-attr3="code" data-attr7="65" data-attr-10="0.7" data-attr11="false" href="/challenges/simple-text-editor?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Simple Text Editor<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 65</span><span class="success-ratio detail-item">Success Rate: 80.72%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="poisonous-plants" data-attr3="code" data-attr7="70" data-attr-10="0.5" data-attr11="false" href="/challenges/poisonous-plants?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Poisonous Plants<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 43.59%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="and-xor-or" data-attr3="code" data-attr7="70" data-attr-10="0.5" data-attr11="false" href="/challenges/and-xor-or?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">AND xor OR<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 62.93%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="waiter" data-attr3="code" data-attr7="75" data-attr-10="0.7" data-attr11="false" href="/challenges/waiter?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Waiter<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Intermediate)</span><span class="max-score detail-item">Max Score: 75</span><span class="success-ratio detail-item">Success Rate: 84.34%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="contacts" data-attr3="code" data-attr7="40" data-attr-10="0.7" data-attr11="false" href="/challenges/contacts?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Contacts<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 40</span><span class="success-ratio detail-item">Success Rate: 67.63%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="no-prefix-set" data-attr3="code" data-attr7="50" data-attr-10="0.5" data-attr11="false" href="/challenges/no-prefix-set?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">No Prefix Set<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 78.42%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="how-well-do-you-know-trees" data-attr3="mcq" data-attr7="5" data-attr-10="0.5" data-attr11="false" href="/challenges/how-well-do-you-know-trees?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title"> Data Structures MCQ 1<div class="card-details pmT"><span class="kind mcq detail-item">Multiple Choice Question</span><span class="max-score detail-item">Max Score: 5</span><span class="success-ratio detail-item">Success Rate: 72.38%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="are-you-an-expert-on-data-structures" data-attr3="mcq" data-attr7="5" data-attr-10="0.5" data-attr11="false" href="/challenges/are-you-an-expert-on-data-structures?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title"> Data Structures MCQ 2<div class="card-details pmT"><span class="kind mcq detail-item">Multiple Choice Question</span><span class="max-score detail-item">Max Score: 5</span><span class="success-ratio detail-item">Success Rate: 60.95%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="are-you-an-expert-on-data-structures-1" data-attr3="mcq" data-attr7="5" data-attr-10="0.5" data-attr11="false" href="/challenges/are-you-an-expert-on-data-structures-1?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title"> Data Structures MCQ 3<div class="card-details pmT"><span class="kind mcq detail-item">Multiple Choice Question</span><span class="max-score detail-item">Max Score: 5</span><span class="success-ratio detail-item">Success Rate: 89.46%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="kindergarten-adventures" data-attr3="code" data-attr7="30" data-attr-10="0.7" data-attr11="false" href="/challenges/kindergarten-adventures?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Kindergarten Adventures<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 30</span><span class="success-ratio detail-item">Success Rate: 51.26%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="cube-summation" data-attr3="code" data-attr7="50" data-attr-10="0.56" data-attr11="false" href="/challenges/cube-summation?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Cube Summation<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="skill detail-item">Problem Solving (Advanced)</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 68.08%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="x-and-his-shots" data-attr3="code" data-attr7="50" data-attr-10="0.7" data-attr11="false" href="/challenges/x-and-his-shots?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Mr. X and His Shots<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 50</span><span class="success-ratio detail-item">Success Rate: 56.98%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="direct-connections" data-attr3="code" data-attr7="60" data-attr-10="0.5448275862068965" data-attr11="false" href="/challenges/direct-connections?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Direct Connections<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 50.83%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="subsequence-weighting" data-attr3="code" data-attr7="60" data-attr-10="0.3947826086956522" data-attr11="false" href="/challenges/subsequence-weighting?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Subsequence Weighting<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 62.83%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="jim-and-the-skyscrapers" data-attr3="code" data-attr7="60" data-attr-10="0.7" data-attr11="false" href="/challenges/jim-and-the-skyscrapers?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Jim and the Skyscrapers<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 60.83%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="palindromic-subsets" data-attr3="code" data-attr7="80" data-attr-10="0.5" data-attr11="false" href="/challenges/palindromic-subsets?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Palindromic Subsets<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 75.61%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="counting-on-a-tree" data-attr3="code" data-attr7="100" data-attr-10="0.1" data-attr11="false" href="/challenges/counting-on-a-tree?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Counting On a Tree<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 72.01%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="polynomial-division" data-attr3="code" data-attr7="60" data-attr-10="0.5" data-attr11="false" href="/challenges/polynomial-division?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Polynomial Division<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 89.18%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="costly-intervals" data-attr3="code" data-attr7="65" data-attr-10="0.5" data-attr11="false" href="/challenges/costly-intervals?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Costly Intervals<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 65</span><span class="success-ratio detail-item">Success Rate: 87.12%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="the-strange-function" data-attr3="code" data-attr7="70" data-attr-10="0.5" data-attr11="false" href="/challenges/the-strange-function?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">The Strange Function<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 70</span><span class="success-ratio detail-item">Success Rate: 75.10%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="self-driving-bus" data-attr3="code" data-attr7="100" data-attr-10="0.3" data-attr11="false" href="/challenges/self-driving-bus?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Self-Driving Bus<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 79.50%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="unique-colors" data-attr3="code" data-attr7="100" data-attr-10="0.3" data-attr11="false" href="/challenges/unique-colors?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Unique Colors<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 86.97%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="fibonacci-numbers-tree" data-attr3="code" data-attr7="100" data-attr-10="0.1" data-attr11="false" href="/challenges/fibonacci-numbers-tree?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Fibonacci Numbers Tree<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 82.12%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="pair-sums" data-attr3="code" data-attr7="80" data-attr-10="0.1" data-attr11="false" href="/challenges/pair-sums?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Pair Sums<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 61.75%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="functional-palindromes" data-attr3="code" data-attr7="80" data-attr-10="0.3" data-attr11="false" href="/challenges/functional-palindromes?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Functional Palindromes<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 80.41%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="lazy-white-falcon" data-attr3="code" data-attr7="100" data-attr-10="0.5" data-attr11="false" href="/challenges/lazy-white-falcon?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Lazy White Falcon<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 80.13%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="ticket-to-ride" data-attr3="code" data-attr7="100" data-attr-10="0.1" data-attr11="false" href="/challenges/ticket-to-ride?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Ticket to Ride<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 84.71%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="heavy-light-white-falcon" data-attr3="code" data-attr7="100" data-attr-10="0.5" data-attr11="false" href="/challenges/heavy-light-white-falcon?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Heavy Light White Falcon<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 81.19%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="little-alexey-and-sum-of-maximums" data-attr3="code" data-attr7="90" data-attr-10="0.3" data-attr11="false" href="/challenges/little-alexey-and-sum-of-maximums?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Sum of the Maximums<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 90</span><span class="success-ratio detail-item">Success Rate: 63.06%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="number-game-on-a-tree" data-attr3="code" data-attr7="80" data-attr-10="0.1" data-attr11="false" href="/challenges/number-game-on-a-tree?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Number Game on a Tree<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 88.31%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="heavy-light-2-white-falcon" data-attr3="code" data-attr7="100" data-attr-10="0.5" data-attr11="false" href="/challenges/heavy-light-2-white-falcon?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Heavy Light 2 White Falcon<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 79.26%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="library-query" data-attr3="code" data-attr7="80" data-attr-10="0.3798449612403101" data-attr11="false" href="/challenges/library-query?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Library Query<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 75.57%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="starfleet" data-attr3="code" data-attr7="100" data-attr-10="0.39436619718309857" data-attr11="false" href="/challenges/starfleet?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Starfleet<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 82.74%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="almost-equal-advanced" data-attr3="code" data-attr7="100" data-attr-10="0.087248322147651" data-attr11="false" href="/challenges/almost-equal-advanced?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Almost Equal - Advanced<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 52.76%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="almost-sorted-interval" data-attr3="code" data-attr7="100" data-attr-10="0.1393011010052657" data-attr11="false" href="/challenges/almost-sorted-interval?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Almost sorted interval<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 33.37%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="burger-happiness" data-attr3="code" data-attr7="100" data-attr-10="0.5" data-attr11="false" href="/challenges/burger-happiness?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Burger Happiness <div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 87.31%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="roy-and-alpha-beta-trees" data-attr3="code" data-attr7="120" data-attr-10="0.5784313725490197" data-attr11="false" href="/challenges/roy-and-alpha-beta-trees?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Roy and alpha-beta trees<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 120</span><span class="success-ratio detail-item">Success Rate: 89.93%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="coloring-tree" data-attr3="code" data-attr7="120" data-attr-10="0.41379310344827586" data-attr11="false" href="/challenges/coloring-tree?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Coloring Tree<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 120</span><span class="success-ratio detail-item">Success Rate: 75.47%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="recalling-early-days-gp-with-trees" data-attr3="code" data-attr7="120" data-attr-10="0.4090909090909091" data-attr11="false" href="/challenges/recalling-early-days-gp-with-trees?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Recalling Early Days GP with Trees<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 120</span><span class="success-ratio detail-item">Success Rate: 87.79%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="swaps-and-sum" data-attr3="code" data-attr7="120" data-attr-10="0.3" data-attr11="false" href="/challenges/swaps-and-sum?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Swaps and Sum<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 120</span><span class="success-ratio detail-item">Success Rate: 59.02%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="arithmetic-progressions" data-attr3="code" data-attr7="80" data-attr-10="0.3652007648183556" data-attr11="false" href="/challenges/arithmetic-progressions?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Arithmetic Progressions<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 80</span><span class="success-ratio detail-item">Success Rate: 71.17%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="coolguy-and-two-subsequences" data-attr3="code" data-attr7="120" data-attr-10="0.3" data-attr11="false" href="/challenges/coolguy-and-two-subsequences?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Coolguy and Two Subsequences<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 120</span><span class="success-ratio detail-item">Success Rate: 76.92%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="white-falcon-and-tree" data-attr3="code" data-attr7="120" data-attr-10="0.5" data-attr11="false" href="/challenges/white-falcon-and-tree?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">White Falcon And Tree<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 120</span><span class="success-ratio detail-item">Success Rate: 89.95%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="subtrees-and-paths" data-attr3="code" data-attr7="120" data-attr-10="0.3" data-attr11="false" href="/challenges/subtrees-and-paths?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Subtrees And Paths<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 120</span><span class="success-ratio detail-item">Success Rate: 82.56%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="triplets" data-attr3="code" data-attr7="90" data-attr-10="0.25119305856832974" data-attr11="false" href="/challenges/triplets?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Triplets<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 90</span><span class="success-ratio detail-item">Success Rate: 34.47%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="beautiful-segments" data-attr3="code" data-attr7="120" data-attr-10="0.1" data-attr11="false" href="/challenges/beautiful-segments?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Beautiful Segments<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 120</span><span class="success-ratio detail-item">Success Rate: 72.01%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="ab0" data-attr3="code" data-attr7="120" data-attr-10="0.07865168539325842" data-attr11="false" href="/challenges/ab0?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Divisibility<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 120</span><span class="success-ratio detail-item">Success Rate: 60.88%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="bst-maintenance" data-attr3="code" data-attr7="140" data-attr-10="0.29901960784313725" data-attr11="false" href="/challenges/bst-maintenance?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">BST maintenance<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 140</span><span class="success-ratio detail-item">Success Rate: 64.31%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="find-maximum-index-product" data-attr3="code" data-attr7="100" data-attr-10="0.7" data-attr11="false" href="/challenges/find-maximum-index-product?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Find Maximum Index Product<div class="card-details pmT"><span class="difficulty medium detail-item">Medium</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 57.10%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="taxicab-drivers-problem" data-attr3="code" data-attr7="150" data-attr-10="0.3" data-attr11="false" href="/challenges/taxicab-drivers-problem?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Taxicab Driver's Problem<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 150</span><span class="success-ratio detail-item">Success Rate: 71.44%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="jagia-playing-with-numbers" data-attr3="code" data-attr7="150" data-attr-10="0.39814814814814814" data-attr11="false" href="/challenges/jagia-playing-with-numbers?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Jaggu Playing with Balloons<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 150</span><span class="success-ratio detail-item">Success Rate: 77.43%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="dynamic-summation" data-attr3="code" data-attr7="150" data-attr-10="0.4787234042553192" data-attr11="false" href="/challenges/dynamic-summation?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Dynamic Summation<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 150</span><span class="success-ratio detail-item">Success Rate: 79.76%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="weird-queries" data-attr3="code" data-attr7="150" data-attr-10="0.4583333333333333" data-attr11="false" href="/challenges/weird-queries?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Two Array Problem<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 150</span><span class="success-ratio detail-item">Success Rate: 75.74%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="rooted-tree" data-attr3="code" data-attr7="150" data-attr-10="0.423728813559322" data-attr11="false" href="/challenges/rooted-tree?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Rooted Tree<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 150</span><span class="success-ratio detail-item">Success Rate: 78.81%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="helix" data-attr3="code" data-attr7="150" data-attr-10="0.3764705882352941" data-attr11="false" href="/challenges/helix?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">The crazy helix<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 150</span><span class="success-ratio detail-item">Success Rate: 65.12%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="net-admin" data-attr3="code" data-attr7="150" data-attr-10="0.4166666666666667" data-attr11="false" href="/challenges/net-admin?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Network administration<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 150</span><span class="success-ratio detail-item">Success Rate: 85.59%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="easy-addition" data-attr3="code" data-attr7="150" data-attr-10="0.1" data-attr11="false" href="/challenges/easy-addition?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Easy Addition<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 150</span><span class="success-ratio detail-item">Success Rate: 84.17%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="find-the-permutation" data-attr3="code" data-attr7="150" data-attr-10="0.1" data-attr11="false" href="/challenges/find-the-permutation?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Find the permutation<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 150</span><span class="success-ratio detail-item">Success Rate: 82.89%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="company-retreat" data-attr3="code" data-attr7="100" data-attr-10="0.3" data-attr11="false" href="/challenges/company-retreat?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Company Retreat<div class="card-details pmT"><span class="difficulty advanced detail-item">Advanced</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 84.21%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="box-operations" data-attr3="code" data-attr7="100" data-attr-10="0.1" data-attr11="false" href="/challenges/box-operations?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Box Operations<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 66.78%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="max-transform" data-attr3="code" data-attr7="100" data-attr-10="0.1" data-attr11="false" href="/challenges/max-transform?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Max Transform<div class="card-details pmT"><span class="difficulty expert detail-item">Expert</span><span class="max-score detail-item">Max Score: 100</span><span class="success-ratio detail-item">Success Rate: 78.13%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a><a class="js-track-click challenge-list-item" data-analytics="ChallengeListChallengeName" data-js-track="Challenge-Title" data-attr1="array-and-queries-1" data-attr3="code" data-attr7="60" data-attr-10="0.5" data-attr11="false" href="/challenges/array-and-queries-1?isFullScreen=true"><div class="single-item challenges-list-view-v2 cursor"><div id="contest-challenges-problem" class="individual-challenge-card-v2 content--list-v2 track_content"><div class="content--list_body"><header class="content--list_header-v2"><div class="challenge-name-details "><div class="pull-left inline-block"><h4 class="challengecard-title">Array and Queries<div class="card-details pmT"><span class="difficulty hard detail-item">Hard</span><span class="max-score detail-item">Max Score: 60</span><span class="success-ratio detail-item">Success Rate: 31.66%</span></div></h4></div></div><span class="bookmark-cta"><button class="ui-btn ui-btn-normal ui-btn-plain star-button" aria-label="Add bookmark"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false"><i class="js-bookmark star-icon ui-icon-star"></i></span></div></button></span><div class="cta-container"><div class="ctas"><div class="challenge-submit-btn"><button class="ui-btn ui-btn-normal primary-cta ui-btn-line-primary ui-btn-styled"><div class="ui-content align-icon-right"><span class="ui-text" aria-hidden="false">Solve Challenge</span></div></button></div></div></div></header></div></div><div class="__react_component_tooltip place-top type-dark " data-id="tooltip"></div></div></a></div></div></section>'''
soup_ds_problems = BeautifulSoup(ds_problems_html, "html.parser")
problems_rows_html = soup_ds_problems.find_all(class_ = "js-track-click challenge-list-item")
print(f'\n --------- There are {len(problems_rows_html)} ds problems --------- \n')
for problem_html in problems_rows_html:
    if len(problem_html.find_all(class_ = "kind mcq detail-item")) >= 1:
        continue
    # Get number of pages in leaderboard
    problem = problem_html["data-attr1"]
    page_lead_html = r.get(f'https://www.hackerrank.com/challenges/{problem}/leaderboard?limit=100',headers=header).text
    soup_lead = BeautifulSoup(page_lead_html, "html.parser")
    no_pages = int(soup_lead.find_all("a", {"class":"pagination-button"})[-2].text)
    ds_no_pages = ds_no_pages +  no_pages 
    ds_list.append(problem)
    # Get problem info
    difficulty = problem_html.find(class_ = "difficulty").text
    max_score = problem_html.find(class_ = "max-score").text.split(": ")[1]
    try:
        skills = problem_html.find(class_ = "skill detail-item").text.split("(")[1][:-1]
    except: 
        skills = "Null"
    print(f'data structures,{problem},{difficulty},{skills},{max_score} ({no_pages} pages)')

print(f'\n --------- There are total {ds_no_pages} pages --------- \n')
# Out:
#  --------- There are 121 ds problems ---------
#
# data structures,dynamic-array,Easy,Basic,15 (1550 pages)
# data structures,arrays-ds,Easy,Basic,10 (7501 pages)
# data structures,2d-array,Easy,Basic,15 (7491 pages)
# data structures,array-left-rotation,Easy,Basic,20 (3459 pages)
# data structures,sparse-arrays,Medium,Basic,25 (3009 pages)
# data structures,crush,Hard,Intermediate,60 (3681 pages)
# data structures,print-the-elements-of-a-linked-list,Easy,Basic,5 (3869 pages)
# data structures,insert-a-node-at-the-tail-of-a-linked-list,Easy,Intermediate,5 (2937 pages)
# data structures,insert-a-node-at-the-head-of-a-linked-list,Easy,Basic,5 (2842 pages)
# data structures,insert-a-node-at-a-specific-position-in-a-linked-list,Easy,Intermediate,5 (2834 pages)
# data structures,delete-a-node-from-a-linked-list,Easy,Basic,5 (2349 pages)
# data structures,print-the-elements-of-a-linked-list-in-reverse,Easy,Basic,5 (2279 pages)
# ...

# %%
alog_no_pages_avg = algo_no_pages/442
ds_no_pages_avg = ds_no_pages/121
print(f'There are {math.floor(alog_no_pages_avg)} pages on average for algorthims problems')
print(f'There are {math.floor(ds_no_pages_avg)} pages on average for data structures problems')
# Out:
# There are 915 pages on average for algorthims problems
# There are 723 pages on average for data structures problems

# %%
# Add column names and empty current data_algo.csv
with open("data_algo.csv","w") as file:
    file.write("problem_id;pl;country;score\n")

# %%
algo_df = pd.read_csv("algo")
ds_df = pd.read_csv("ds")

# %%
no_problems = len(algo_df)
for i in range(0,no_problems,math.ceil(1/0.1)):
    start = time()
    print(f'--- Scraping problem {i} - {algo_df.iloc[i]["problem_name"]} ---')
    os.write(1,f'--- Scraping problem {i} - {algo_df.iloc[i]["problem_name"]} ---'.encode())
    output_to_csv("data_algo.csv", scrape_problem(algo_df.iloc[i]["problem_name"],i,0.1))
    #output_to_csv("data_algo.csv", scrape_problem("definite-random-walks",i,0.1))
    end = time()
    os.write(1,f'Scraped problem {algo_df.iloc[i]["problem_name"]}, time taken: {round((end - start)/60,3)/60} mins'.encode())
    print(f'Scraped problem {algo_df.iloc[i]["problem_name"]}, time taken: {round((end - start)/60,3)/60} mins')
# Out:
# Couldn't find program: 'false'

# %%
# %%script false --no-raise-error
# # Add column names and empty current data_ds.csv
# with open("data_ds.csv","w") as file:
#     file.write("problem_id;pl;country;score\n")
# Out:
# Couldn't find program: 'false'

# %%
#%%script false --no-raise-error
no_problems = len(ds_df)
for i in range(10,no_problems,math.ceil(1/0.1)):
    start = time()
    print(f'\n--- Scraping problem {i} - {ds_df.iloc[i]["problem_name"]} --- \n')
    os.write(1,f'--- Scraping problem {i} - {ds_df.iloc[i]["problem_name"]} ---'.encode())
    output_to_csv("data_ds.csv", scrape_problem(ds_df.iloc[i]["problem_name"],i,0.1))
    #output_to_csv("data_ds.csv", scrape_problem("definite-random-walks",i,0.1))
    end = time()
    os.write(1,f'Scraped problem {ds_df.iloc[i]["problem_name"]}, time taken: {round((end - start)/60,3)/60} mins'.encode())
    print(f'Scraped problem {ds_df.iloc[i]["problem_name"]}, time taken: {round((end - start)/60,3)/60} mins')
# Out:
# --- Scraping problem 10 - delete-a-node-from-a-linked-list ---
#
# Number of pages in leaderboard: 239
# Page being scraped rightnow: https://www.hackerrank.com/challenges/delete-a-node-from-a-linked-list/leaderboard?filter=c&filter_on=language&limit=100&page=1
# 0% Scraped
# 5.0% of page is scraped
# 10.0% of page is scraped
# 15.0% of page is scraped
# 20.0% of page is scraped
# 25.0% of page is scraped
# 30.0% of page is scraped
# 35.0% of page is scraped
# 40.0% of page is scraped
# 45.0% of page is scraped
# 50.0% of page is scraped
# 55.0% of page is scraped
# 60.0% of page is scraped
# 65.0% of page is scraped
# 70.0% of page is scraped
# 75.0% of page is scraped
# 80.0% of page is scraped
# 85.0% of page is scraped
# 90.0% of page is scraped
# 95.0% of page is scraped
# 100.0% of page is scraped
# Page 1 finished scraping
#
#
# ...
